# %%
# https://github.com/weibycn/fund

# %%
import requests
import json
import re
from datetime import datetime
import numpy as np
from copy import deepcopy

# %%
# def get_all_funds():
    api = "http://fund.eastmoney.com/js/fundcode_search.js"
    requests.get(api)
api_

# %%
api = "http://fund.eastmoney.com/js/fundcode_search.js"
res = requests.get(api)

# %%
funds = json.loads(res.content.decode("utf-8")[9:-1])
funds = [{"id": id, "code": code, "name": name, "kind": kind, "fullcode": fullcode} for id, code, name, kind, fullcode in funds]

# %%
funds
# Out:
# [{'id': '000001',
#   'code': 'HXCZHH',
#   'name': '华夏成长混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUAXIACHENGZHANGHUNHE'},
#  {'id': '000002',
#   'code': 'HXCZHH',
#   'name': '华夏成长混合(后端)',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUAXIACHENGZHANGHUNHE'},
#  {'id': '000003',
#   'code': 'ZHKZZZQA',
#   'name': '中海可转债债券A',
#   'kind': '债券型-可转债',
#   'fullcode': 'ZHONGHAIKEZHUANZHAIZHAIQUANA'},
#  {'id': '000004',
#   'code': 'ZHKZZZQC',
#   'name': '中海可转债债券C',
#   'kind': '债券型-可转债',
#   'fullcode': 'ZHONGHAIKEZHUANZHAIZHAIQUANC'},
#  {'id': '000005',
#   'code': 'JSZQXYDQZQ',
#   'name': '嘉实增强信用定期债券',
#   'kind': '债券型-长债',
#   'fullcode': 'JIASHIZENGQIANGXINYONGDINGQIZHAIQUAN'},
#  {'id': '000006',
#   'code': 'XBLDLHCZHHA',
#   'name': '西部利得量化成长混合A',
#   'kind': '混合型-偏股',
#   'fullcode': 'XIBULIDELIANGHUACHENGZHANGHUNHEA'},
#  {'id': '000008',
#   'code': 'JSZZ500ETFLJA',
#   'name': '嘉实中证500ETF联接A',
#   'kind': '指数型-股票',
#   'fullcode': 'JIASHIZHONGZHENG500ETFLIANJIEA'},
#  {'id': '000009',
#   'code': 'YFDTTLCHBA',
#   'name': '易方达天天理财货币A',
#   'kind': '货币型',
#   'fullcode': 'YIFANGDATIANTIANLICAIHUOBIA'},
#  {'id': '000010',
#   'code': 'YFDTTLCHBB',
#   'name': '易方达天天理财货币B',
#   'kind': '货币型',
#   'fullcode': 'YIFANGDATIANTIANLICAIHUOBIB'},
#  {'id': '000011',
#   'code': 'HXDPJXHHA',
#   'name': '华夏大盘精选混合A',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUAXIADAPANJINGXUANHUNHEA'},
#  {'id': '000012',
#   'code': 'HXDPJXHHA',
#   'name': '华夏大盘精选混合A(后端)',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUAXIADAPANJINGXUANHUNHEA'},
#  {'id': '000013',
#   'code': 'YFDTTLCHBR',
#   'name': '易方达天天理财货币R',
#   'kind': '货币型',
#   'fullcode': 'YIFANGDATIANTIANLICAIHUOBIR'},
#  {'id': '000014',
#   'code': 'HXJLZQ',
#   'name': '华夏聚利债券',
#   'kind': '债券型-混合债',
#   'fullcode': 'HUAXIAJULIZHAIQUAN'},
#  {'id': '000015',
#   'code': 'HXCZZQA',
#   'name': '华夏纯债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUAXIACHUNZHAIZHAIQUANA'},
#  {'id': '000016',
#   'code': 'HXCZZQC',
#   'name': '华夏纯债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'HUAXIACHUNZHAIZHAIQUANC'},
#  {'id': '000017',
#   'code': 'CTKCXHH',
#   'name': '财通可持续混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'CAITONGKECHIXUHUNHE'},
#  {'id': '000020',
#   'code': 'JSCCPZTZHH',
#   'name': '景顺长城品质投资混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'JINGSHUNCHANGCHENGPINZHITOUZIHUNHE'},
#  {'id': '000021',
#   'code': 'HXYSZZHH',
#   'name': '华夏优势增长混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUAXIAYOUSHIZENGZHANGHUNHE'},
#  {'id': '000024',
#   'code': 'DMSLZQZQA',
#   'name': '大摩双利增强债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'DAMOSHUANGLIZENGQIANGZHAIQUANA'},
#  {'id': '000025',
#   'code': 'DMSLZQZQC',
#   'name': '大摩双利增强债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'DAMOSHUANGLIZENGQIANGZHAIQUANC'},
#  {'id': '000028',
#   'code': 'HFAXZQ',
#   'name': '华富安鑫债券',
#   'kind': '债券型-混合债',
#   'fullcode': 'HUAFUANXINZHAIQUAN'},
#  {'id': '000029',
#   'code': 'FGHGCLLHPZHHA',
#   'name': '富国宏观策略灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'FUGUOHONGGUANCELUELINGHUOPEIZHIHUNHEA'},
#  {'id': '000030',
#   'code': 'CCHXYXHH',
#   'name': '长城核心优选混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'CHANGCHENGHEXINYOUXUANHUNHE'},
#  {'id': '000031',
#   'code': 'HXFXHH',
#   'name': '华夏复兴混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUAXIAFUXINGHUNHE'},
#  {'id': '000032',
#   'code': 'YFDXYZZQA',
#   'name': '易方达信用债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'YIFANGDAXINYONGZHAIZHAIQUANA'},
#  {'id': '000033',
#   'code': 'YFDXYZZQC',
#   'name': '易方达信用债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'YIFANGDAXINYONGZHAIZHAIQUANC'},
#  {'id': '000037',
#   'code': 'GFJNZQA',
#   'name': '广发景宁债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'GUANGFAJINGNINGZHAIQUANA'},
#  {'id': '000039',
#   'code': 'NYGZZHH',
#   'name': '农银高增长混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'NONGYINGAOZENGZHANGHUNHE'},
#  {'id': '000041',
#   'code': 'HXQQGPQDII',
#   'name': '华夏全球股票(QDII)',
#   'kind': 'QDII',
#   'fullcode': 'HUAXIAQUANQIUGUPIAOQDII'},
#  {'id': '000042',
#   'code': 'CTZZESG100ZSZQA',
#   'name': '财通中证ESG100指数增强A',
#   'kind': '指数型-股票',
#   'fullcode': 'CAITONGZHONGZHENGESG100ZHISHUZENGQIANGA'},
#  {'id': '000043',
#   'code': 'JSMGCZGPRMB',
#   'name': '嘉实美国成长股票人民币',
#   'kind': 'QDII',
#   'fullcode': 'JIASHIMEIGUOCHENGZHANGGUPIAORENMINBI'},
#  {'id': '000044',
#   'code': 'JSMGCZGPMYXH',
#   'name': '嘉实美国成长股票美元现汇',
#   'kind': 'QDII',
#   'fullcode': 'JIASHIMEIGUOCHENGZHANGGUPIAOMEIYUANXIANHUI'},
#  {'id': '000045',
#   'code': 'GYCYZZQA',
#   'name': '工银产业债债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'GONGYINCHANYEZHAIZHAIQUANA'},
#  {'id': '000046',
#   'code': 'GYCYZZQB',
#   'name': '工银产业债债券B',
#   'kind': '债券型-混合债',
#   'fullcode': 'GONGYINCHANYEZHAIZHAIQUANB'},
#  {'id': '000047',
#   'code': 'HXSZZQA',
#   'name': '华夏双债债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'HUAXIASHUANGZHAIZHAIQUANA'},
#  {'id': '000048',
#   'code': 'HXSZZQC',
#   'name': '华夏双债债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'HUAXIASHUANGZHAIZHAIQUANC'},
#  {'id': '000049',
#   'code': 'ZYBPQQZYDQZZS',
#   'name': '中银标普全球资源等权重指数',
#   'kind': 'QDII',
#   'fullcode': 'ZHONGYINBIAOPUQUANQIUZIYUANDENGQUANZHONGZHISHU'},
#  {'id': '000051',
#   'code': 'HXHS300ETFLJA',
#   'name': '华夏沪深300ETF联接A',
#   'kind': '指数型-股票',
#   'fullcode': 'HUAXIAHUSHEN300ETFLIANJIEA'},
#  {'id': '000053',
#   'code': 'PHYCYNDKZQ',
#   'name': '鹏华永诚一年定开债券',
#   'kind': '债券型-长债',
#   'fullcode': 'PENGHUAYONGCHENGYINIANDINGKAIZHAIQUAN'},
#  {'id': '000054',
#   'code': 'PHSZZLZQ',
#   'name': '鹏华双债增利债券',
#   'kind': '债券型-混合债',
#   'fullcode': 'PENGHUASHUANGZHAIZENGLIZHAIQUAN'},
#  {'id': '000055',
#   'code': 'GFNSDK100MYXHA',
#   'name': '广发纳斯达克100美元现汇A',
#   'kind': 'QDII',
#   'fullcode': 'GUANGFANASIDAKE100MEIYUANXIANHUIA'},
#  {'id': '000056',
#   'code': 'JXXFSJHH',
#   'name': '建信消费升级混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'JIANXINXIAOFEISHENGJIHUNHE'},
#  {'id': '000057',
#   'code': 'ZYXFZTHH',
#   'name': '中银消费主题混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'ZHONGYINXIAOFEIZHUTIHUNHE'},
#  {'id': '000058',
#   'code': 'GLAATLHPZHH',
#   'name': '国联安安泰灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOLIANANANTAILINGHUOPEIZHIHUNHE'},
#  {'id': '000059',
#   'code': 'GLAZZYY100A',
#   'name': '国联安中证医药100A',
#   'kind': '指数型-股票',
#   'fullcode': 'GUOLIANANZHONGZHENGYIYAO100A'},
#  {'id': '000061',
#   'code': 'HXSSHH',
#   'name': '华夏盛世混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUAXIASHENGSHIHUNHE'},
#  {'id': '000063',
#   'code': 'CSDZXXZTLHPZHH',
#   'name': '长盛电子信息主题灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'CHANGSHENGDIANZIXINXIZHUTILINGHUOPEIZHIHUNHE'},
#  {'id': '000064',
#   'code': 'DM18GYDKZ',
#   'name': '大摩18个月定开债',
#   'kind': '债券型-长债',
#   'fullcode': 'DAMO18GEYUEDINGKAIZHAI'},
#  {'id': '000065',
#   'code': 'GFJDQDHH',
#   'name': '国富焦点驱动混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOFUJIAODIANQUDONGHUNHE'},
#  {'id': '000066',
#   'code': 'NAHXHH',
#   'name': '诺安鸿鑫混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'NUOANHONGXINHUNHE'},
#  {'id': '000067',
#   'code': 'MSJYZZYXA',
#   'name': '民生加银转债优选A',
#   'kind': '债券型-可转债',
#   'fullcode': 'MINSHENGJIAYINZHUANZHAIYOUXUANA'},
#  {'id': '000068',
#   'code': 'MSJYZZYXC',
#   'name': '民生加银转债优选C',
#   'kind': '债券型-可转债',
#   'fullcode': 'MINSHENGJIAYINZHUANZHAIYOUXUANC'},
#  {'id': '000069',
#   'code': 'GTRYZGDJZQA',
#   'name': '国投瑞银中高等级债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'GUOTOURUIYINZHONGGAODENGJIZHAIQUANA'},
#  {'id': '000070',
#   'code': 'GTRYZGDJZQC',
#   'name': '国投瑞银中高等级债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'GUOTOURUIYINZHONGGAODENGJIZHAIQUANC'},
#  {'id': '000071',
#   'code': 'HXHSETFLJA',
#   'name': '华夏恒生ETF联接A',
#   'kind': 'QDII',
#   'fullcode': 'HUAXIAHENGSHENGETFLIANJIEA'},
#  {'id': '000072',
#   'code': 'HAWJHBHH',
#   'name': '华安稳健回报混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUAANWENJIANHUIBAOHUNHE'},
#  {'id': '000073',
#   'code': 'STMGCZDLHH',
#   'name': '上投摩根成长动力混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'SHANGTOUMOGENCHENGZHANGDONGLIHUNHE'},
#  {'id': '000074',
#   'code': 'GYXYCZYNDKZA',
#   'name': '工银信用纯债一年定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'GONGYINXINYONGCHUNZHAIYINIANDINGKAIZHAIA'},
#  {'id': '000075',
#   'code': 'HXHSETFLJXH',
#   'name': '华夏恒生ETF联接现汇',
#   'kind': 'QDII',
#   'fullcode': 'HUAXIAHENGSHENGETFLIANJIEXIANHUI'},
#  {'id': '000076',
#   'code': 'HXHSETFLJXC',
#   'name': '华夏恒生ETF联接现钞',
#   'kind': 'QDII',
#   'fullcode': 'HUAXIAHENGSHENGETFLIANJIEXIANCHAO'},
#  {'id': '000077',
#   'code': 'GYXYCZYNDKZC',
#   'name': '工银信用纯债一年定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'GONGYINXINYONGCHUNZHAIYINIANDINGKAIZHAIC'},
#  {'id': '000078',
#   'code': 'GYXYCZSGYDKZA',
#   'name': '工银信用纯债三个月定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'GONGYINXINYONGCHUNZHAISANGEYUEDINGKAIZHAIA'},
#  {'id': '000079',
#   'code': 'GYXYCZSGYDKZC',
#   'name': '工银信用纯债三个月定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'GONGYINXINYONGCHUNZHAISANGEYUEDINGKAIZHAIC'},
#  {'id': '000080',
#   'code': 'TZKZZZQZQA',
#   'name': '天治可转债增强债券A',
#   'kind': '债券型-可转债',
#   'fullcode': 'TIANZHIKEZHUANZHAIZENGQIANGZHAIQUANA'},
#  {'id': '000081',
#   'code': 'TZKZZZQZQC',
#   'name': '天治可转债增强债券C',
#   'kind': '债券型-可转债',
#   'fullcode': 'TIANZHIKEZHUANZHAIZENGQIANGZHAIQUANC'},
#  {'id': '000082',
#   'code': 'JSYJAEFGP',
#   'name': '嘉实研究阿尔法股票',
#   'kind': '股票型',
#   'fullcode': 'JIASHIYANJIUAERFAGUPIAO'},
#  {'id': '000083',
#   'code': 'HTFXFHYHH',
#   'name': '汇添富消费行业混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUITIANFUXIAOFEIHANGYEHUNHE'},
#  {'id': '000084',
#   'code': 'BSAYZQA',
#   'name': '博时安盈债券A',
#   'kind': '债券型-中短债',
#   'fullcode': 'BOSHIANYINGZHAIQUANA'},
#  {'id': '000085',
#   'code': 'BSAYZQC',
#   'name': '博时安盈债券C',
#   'kind': '债券型-中短债',
#   'fullcode': 'BOSHIANYINGZHAIQUANC'},
#  {'id': '000086',
#   'code': 'NFWL1NDKZA',
#   'name': '南方稳利1年定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'NANFANGWENLI1NIANDINGKAIZHAIA'},
#  {'id': '000087',
#   'code': 'JSZZJBGZETFLJA',
#   'name': '嘉实中证金边国债ETF联接A',
#   'kind': '债券型-长债',
#   'fullcode': 'JIASHIZHONGZHENGJINBIANGUOZHAIETFLIANJIEA'},
#  {'id': '000088',
#   'code': 'JSZZJBGZETFLJC',
#   'name': '嘉实中证金边国债ETF联接C',
#   'kind': '债券型-长债',
#   'fullcode': 'JIASHIZHONGZHENGJINBIANGUOZHAIETFLIANJIEC'},
#  {'id': '000089',
#   'code': 'MSJYGDJXYZC',
#   'name': '民生加银高等级信用债C',
#   'kind': '债券型-长债',
#   'fullcode': 'MINSHENGJIAYINGAODENGJIXINYONGZHAIC'},
#  {'id': '000090',
#   'code': 'MSJYGDJXYZA',
#   'name': '民生加银高等级信用债A',
#   'kind': '债券型-长债',
#   'fullcode': 'MINSHENGJIAYINGAODENGJIXINYONGZHAIA'},
#  {'id': '000103',
#   'code': 'GTZGQYJWGSYZ',
#   'name': '国泰中国企业境外高收益债',
#   'kind': 'QDII',
#   'fullcode': 'GUOTAIZHONGGUOQIYEJINGWAIGAOSHOUYIZHAI'},
#  {'id': '000104',
#   'code': 'HCWLWJTLZQA',
#   'name': '华宸未来稳健添利债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUACHENWEILAIWENJIANTIANLIZHAIQUANA'},
#  {'id': '000105',
#   'code': 'JXAXHBZQA',
#   'name': '建信安心回报债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'JIANXINANXINHUIBAOZHAIQUANA'},
#  {'id': '000106',
#   'code': 'JXAXHBZQC',
#   'name': '建信安心回报债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'JIANXINANXINHUIBAOZHAIQUANC'},
#  {'id': '000107',
#   'code': 'FGWJZQZQAB',
#   'name': '富国稳健增强债券A/B',
#   'kind': '债券型-混合债',
#   'fullcode': 'FUGUOWENJIANZENGQIANGZHAIQUANAB'},
#  {'id': '000108',
#   'code': 'FGWJZQZQAB',
#   'name': '富国稳健增强债券A/B(后端)',
#   'kind': '债券型-混合债',
#   'fullcode': 'FUGUOWENJIANZENGQIANGZHAIQUANAB'},
#  {'id': '000109',
#   'code': 'FGWJZQZQC',
#   'name': '富国稳健增强债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'FUGUOWENJIANZENGQIANGZHAIQUANC'},
#  {'id': '000110',
#   'code': 'JYYAHHA',
#   'name': '金鹰元安混合A',
#   'kind': '混合型-偏债',
#   'fullcode': 'JINYINGYUANANHUNHEA'},
#  {'id': '000111',
#   'code': 'YFDCZ1NDKZA',
#   'name': '易方达纯债1年定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'YIFANGDACHUNZHAI1NIANDINGKAIZHAIA'},
#  {'id': '000112',
#   'code': 'YFDCZ1NDKZC',
#   'name': '易方达纯债1年定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'YIFANGDACHUNZHAI1NIANDINGKAIZHAIC'},
#  {'id': '000113',
#   'code': 'JSRYBDQZQAB',
#   'name': '嘉实如意宝定期债券A/B',
#   'kind': '债券型-长债',
#   'fullcode': 'JIASHIRUYIBAODINGQIZHAIQUANAB'},
#  {'id': '000114',
#   'code': 'JSRYBDQZQAB',
#   'name': '嘉实如意宝定期债券A/B(后端)',
#   'kind': '债券型-长债',
#   'fullcode': 'JIASHIRUYIBAODINGQIZHAIQUANAB'},
#  {'id': '000115',
#   'code': 'JSRYBDQZQC',
#   'name': '嘉实如意宝定期债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'JIASHIRUYIBAODINGQIZHAIQUANC'},
#  {'id': '000116',
#   'code': 'JSFYCZDQZQ',
#   'name': '嘉实丰益纯债定期债券',
#   'kind': '债券型-长债',
#   'fullcode': 'JIASHIFENGYICHUNZHAIDINGQIZHAIQUAN'},
#  {'id': '000117',
#   'code': 'GFLDPZHH',
#   'name': '广发轮动配置混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'GUANGFALUNDONGPEIZHIHUNHE'},
#  {'id': '000118',
#   'code': 'GFJXZQA',
#   'name': '广发聚鑫债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'GUANGFAJUXINZHAIQUANA'},
#  {'id': '000119',
#   'code': 'GFJXZQC',
#   'name': '广发聚鑫债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'GUANGFAJUXINZHAIQUANC'},
#  {'id': '000120',
#   'code': 'ZYMLZGHH',
#   'name': '中银美丽中国混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'ZHONGYINMEILIZHONGGUOHUNHE'},
#  {'id': '000121',
#   'code': 'HXYFHHA',
#   'name': '华夏永福混合A',
#   'kind': '混合型-偏债',
#   'fullcode': 'HUAXIAYONGFUHUNHEA'},
#  {'id': '000122',
#   'code': 'HTFSYZZQA',
#   'name': '汇添富实业债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUITIANFUSHIYEZHAIZHAIQUANA'},
#  {'id': '000123',
#   'code': 'HTFSYZZQC',
#   'name': '汇添富实业债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'HUITIANFUSHIYEZHAIZHAIQUANC'},
#  {'id': '000124',
#   'code': 'HBFWYXHH',
#   'name': '华宝服务优选混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUABAOFUWUYOUXUANHUNHE'},
#  {'id': '000126',
#   'code': 'ZSARHH',
#   'name': '招商安润混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHAOSHANGANRUNHUNHE'},
#  {'id': '000127',
#   'code': 'NYHYLXHH',
#   'name': '农银行业领先混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'NONGYINHANGYELINGXIANHUNHE'},
#  {'id': '000128',
#   'code': 'DCJADRZQA',
#   'name': '大成景安短融债券A',
#   'kind': '债券型-中短债',
#   'fullcode': 'DACHENGJINGANDUANRONGZHAIQUANA'},
#  {'id': '000129',
#   'code': 'DCJADRZQB',
#   'name': '大成景安短融债券B',
#   'kind': '债券型-中短债',
#   'fullcode': 'DACHENGJINGANDUANRONGZHAIQUANB'},
#  {'id': '000130',
#   'code': 'DCJXXYZZQA',
#   'name': '大成景兴信用债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'DACHENGJINGXINGXINYONGZHAIZHAIQUANA'},
#  {'id': '000131',
#   'code': 'DCJXXYZZQC',
#   'name': '大成景兴信用债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'DACHENGJINGXINGXINYONGZHAIZHAIQUANC'},
#  {'id': '000134',
#   'code': 'ZXBCJHZQA',
#   'name': '中信保诚嘉鸿债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'ZHONGXINBAOCHENGJIAHONGZHAIQUANA'},
#  {'id': '000135',
#   'code': 'ZXBCJHZQC',
#   'name': '中信保诚嘉鸿债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'ZHONGXINBAOCHENGJIAHONGZHAIQUANC'},
#  {'id': '000136',
#   'code': 'MSJYCLJXHHA',
#   'name': '民生加银策略精选混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'MINSHENGJIAYINCELUEJINGXUANHUNHEA'},
#  {'id': '000137',
#   'code': 'MSJYSSZLZQA',
#   'name': '民生加银岁岁增利债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'MINSHENGJIAYINSUISUIZENGLIZHAIQUANA'},
#  {'id': '000138',
#   'code': 'MSJYSSZLZQC',
#   'name': '民生加银岁岁增利债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'MINSHENGJIAYINSUISUIZENGLIZHAIQUANC'},
#  {'id': '000139',
#   'code': 'FGGYQYZZQAB',
#   'name': '富国国有企业债债券A/B',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOGUOYOUQIYEZHAIZHAIQUANAB'},
#  {'id': '000140',
#   'code': 'FGGYQYZZQAB',
#   'name': '富国国有企业债债券A/B(后端)',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOGUOYOUQIYEZHAIZHAIQUANAB'},
#  {'id': '000141',
#   'code': 'FGGYQYZZQC',
#   'name': '富国国有企业债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOGUOYOUQIYEZHAIZHAIQUANC'},
#  {'id': '000142',
#   'code': 'RTZQSYZQA',
#   'name': '融通增强收益债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'RONGTONGZENGQIANGSHOUYIZHAIQUANA'},
#  {'id': '000143',
#   'code': 'PHSZJLZQA',
#   'name': '鹏华双债加利债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'PENGHUASHUANGZHAIJIALIZHAIQUANA'},
#  {'id': '000147',
#   'code': 'YFDGDJXYZZQA',
#   'name': '易方达高等级信用债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'YIFANGDAGAODENGJIXINYONGZHAIZHAIQUANA'},
#  {'id': '000148',
#   'code': 'YFDGDJXYZZQC',
#   'name': '易方达高等级信用债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'YIFANGDAGAODENGJIXINYONGZHAIZHAIQUANC'},
#  {'id': '000149',
#   'code': 'HASZTLZQA',
#   'name': '华安双债添利债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUAANSHUANGZHAITIANLIZHAIQUANA'},
#  {'id': '000150',
#   'code': 'HASZTLZQC',
#   'name': '华安双债添利债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'HUAANSHUANGZHAITIANLIZHAIQUANC'},
#  {'id': '000152',
#   'code': 'DCJXCZZQA',
#   'name': '大成景旭纯债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'DACHENGJINGXUCHUNZHAIZHAIQUANA'},
#  {'id': '000153',
#   'code': 'DCJXCZZQC',
#   'name': '大成景旭纯债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'DACHENGJINGXUCHUNZHAIZHAIQUANC'},
#  {'id': '000154',
#   'code': 'FGHS300ZSZQA',
#   'name': '富国沪深300指数增强A(后端)',
#   'kind': '指数型-股票',
#   'fullcode': 'FUGUOHUSHEN300ZHISHUZENGQIANGA'},
#  {'id': '000155',
#   'code': 'FGTZTSZTLDHH',
#   'name': '富国通胀通缩主题轮动混合(后端)',
#   'kind': '混合型-偏股',
#   'fullcode': 'FUGUOTONGZHANGTONGSUOZHUTILUNDONGHUNHE'},
#  {'id': '000157',
#   'code': 'FGQQKJHLWQDII',
#   'name': '富国全球科技互联网(QDII)(后端)',
#   'kind': 'QDII',
#   'fullcode': 'FUGUOQUANQIUKEJIHULIANWANGQDII'},
#  {'id': '000158',
#   'code': 'FGDTHBHH',
#   'name': '富国低碳环保混合(后端)',
#   'kind': '混合型-偏股',
#   'fullcode': 'FUGUODITANHUANBAOHUNHE'},
#  {'id': '000159',
#   'code': 'FGGXJSCYHH',
#   'name': '富国高新技术产业混合(后端)',
#   'kind': '混合型-偏股',
#   'fullcode': 'FUGUOGAOXINJISHUCHANYEHUNHE'},
#  {'id': '000160',
#   'code': 'FGQHBDKZAB',
#   'name': '富国强回报定开债A/B(后端)',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOQIANGHUIBAODINGKAIZHAIAB'},
#  {'id': '000161',
#   'code': 'FGHGCLLHPZHHA',
#   'name': '富国宏观策略灵活配置混合A(后端)',
#   'kind': '混合型-灵活',
#   'fullcode': 'FUGUOHONGGUANCELUELINGHUOPEIZHIHUNHEA'},
#  {'id': '000162',
#   'code': 'FGZGZXPHHQDIIRMB',
#   'name': '富国中国中小盘混合(QDII)人民币(后端)',
#   'kind': 'QDII',
#   'fullcode': 'FUGUOZHONGGUOZHONGXIAOPANHUNHEQDIIRENMINBI'},
#  {'id': '000164',
#   'code': 'FGSZZSETFLJA',
#   'name': '富国上证指数ETF联接A(后端)',
#   'kind': '指数型-股票',
#   'fullcode': 'FUGUOSHANGZHENGZHISHUETFLIANJIEA'},
#  {'id': '000165',
#   'code': 'GTRYCLJXHH',
#   'name': '国投瑞银策略精选混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOTOURUIYINCELUEJINGXUANHUNHE'},
#  {'id': '000166',
#   'code': 'ZHXXCYJXHH',
#   'name': '中海信息产业精选混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'ZHONGHAIXINXICHANYEJINGXUANHUNHE'},
#  {'id': '000167',
#   'code': 'GFJYLHPZHHA',
#   'name': '广发聚优灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUANGFAJUYOULINGHUOPEIZHIHUNHEA'},
#  {'id': '000171',
#   'code': 'YFDYFHBZQ',
#   'name': '易方达裕丰回报债券',
#   'kind': '债券型-混合债',
#   'fullcode': 'YIFANGDAYUFENGHUIBAOZHAIQUAN'},
#  {'id': '000172',
#   'code': 'HTBRLHZQHHA',
#   'name': '华泰柏瑞量化增强混合A',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUATAIBAIRUILIANGHUAZENGQIANGHUNHEA'},
#  {'id': '000173',
#   'code': 'HTFML30HH',
#   'name': '汇添富美丽30混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUITIANFUMEILI30HUNHE'},
#  {'id': '000174',
#   'code': 'HTFGXZZQA',
#   'name': '汇添富高息债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUITIANFUGAOXIZHAIZHAIQUANA'},
#  {'id': '000175',
#   'code': 'HTFGXZZQC',
#   'name': '汇添富高息债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'HUITIANFUGAOXIZHAIZHAIQUANC'},
#  {'id': '000176',
#   'code': 'JSHS300ZSYJZQ',
#   'name': '嘉实沪深300指数研究增强',
#   'kind': '指数型-股票',
#   'fullcode': 'JIASHIHUSHEN300ZHISHUYANJIUZENGQIANG'},
#  {'id': '000179',
#   'code': 'GFMGFDCZS',
#   'name': '广发美国房地产指数',
#   'kind': 'QDII',
#   'fullcode': 'GUANGFAMEIGUOFANGDICHANZHISHU'},
#  {'id': '000180',
#   'code': 'GFMGFDCZSXH',
#   'name': '广发美国房地产指数现汇',
#   'kind': 'QDII',
#   'fullcode': 'GUANGFAMEIGUOFANGDICHANZHISHUXIANHUI'},
#  {'id': '000181',
#   'code': 'JSCCSJJLZQA',
#   'name': '景顺长城四季金利债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'JINGSHUNCHANGCHENGSIJIJINLIZHAIQUANA'},
#  {'id': '000182',
#   'code': 'JSCCSJJLZQC',
#   'name': '景顺长城四季金利债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'JINGSHUNCHANGCHENGSIJIJINLIZHAIQUANC'},
#  {'id': '000183',
#   'code': 'JSFYCLDQZQ',
#   'name': '嘉实丰益策略定期债券',
#   'kind': '债券型-长债',
#   'fullcode': 'JIASHIFENGYICELUEDINGQIZHAIQUAN'},
#  {'id': '000184',
#   'code': 'GYTFZQA',
#   'name': '工银添福债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'GONGYINTIANFUZHAIQUANA'},
#  {'id': '000185',
#   'code': 'GYTFZQB',
#   'name': '工银添福债券B',
#   'kind': '债券型-混合债',
#   'fullcode': 'GONGYINTIANFUZHAIQUANB'},
#  {'id': '000186',
#   'code': 'HTBRJJHZQ',
#   'name': '华泰柏瑞季季红债券',
#   'kind': '债券型-长债',
#   'fullcode': 'HUATAIBAIRUIJIJIHONGZHAIQUAN'},
#  {'id': '000187',
#   'code': 'HTBRFSCZZQA',
#   'name': '华泰柏瑞丰盛纯债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUATAIBAIRUIFENGSHENGCHUNZHAIZHAIQUANA'},
#  {'id': '000188',
#   'code': 'HTBRFSCZZQC',
#   'name': '华泰柏瑞丰盛纯债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'HUATAIBAIRUIFENGSHENGCHUNZHAIZHAIQUANC'},
#  {'id': '000189',
#   'code': 'YFDFHZQA',
#   'name': '易方达丰华债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'YIFANGDAFENGHUAZHAIQUANA'},
#  {'id': '000190',
#   'code': 'ZYXHBLHPZHHA',
#   'name': '中银新回报灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHONGYINXINHUIBAOLINGHUOPEIZHIHUNHEA'},
#  {'id': '000191',
#   'code': 'FGXYZZQAB',
#   'name': '富国信用债债券A/B',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOXINYONGZHAIZHAIQUANAB'},
#  {'id': '000192',
#   'code': 'FGXYZZQC',
#   'name': '富国信用债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOXINYONGZHAIZHAIQUANC'},
#  {'id': '000194',
#   'code': 'YHXYSJHZQA',
#   'name': '银华信用四季红债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'YINHUAXINYONGSIJIHONGZHAIQUANA'},
#  {'id': '000195',
#   'code': 'GYCZSYHHA',
#   'name': '工银成长收益混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'GONGYINCHENGZHANGSHOUYIHUNHEA'},
#  {'id': '000196',
#   'code': 'GYCZSYHHB',
#   'name': '工银成长收益混合B',
#   'kind': '混合型-灵活',
#   'fullcode': 'GONGYINCHENGZHANGSHOUYIHUNHEB'},
#  {'id': '000197',
#   'code': 'FGMBSYYNQCZZQ',
#   'name': '富国目标收益一年期纯债债券',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOMUBIAOSHOUYIYINIANQICHUNZHAIZHAIQUAN'},
#  {'id': '000198',
#   'code': 'THYEBHB',
#   'name': '天弘余额宝货币',
#   'kind': '货币型',
#   'fullcode': 'TIANHONGYUEBAOHUOBI'},
#  {'id': '000199',
#   'code': 'GTLHCLSYHH',
#   'name': '国泰量化策略收益混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'GUOTAILIANGHUACELUESHOUYIHUNHE'},
#  {'id': '000200',
#   'code': 'BSSSZLYNDKZ',
#   'name': '博时岁岁增利一年定开债',
#   'kind': '债券型-长债',
#   'fullcode': 'BOSHISUISUIZENGLIYINIANDINGKAIZHAI'},
#  {'id': '000201',
#   'code': 'NATXYNDKZA',
#   'name': '诺安泰鑫一年定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'NUOANTAIXINYINIANDINGKAIZHAIA'},
#  {'id': '000203',
#   'code': 'GFRRSYHBA',
#   'name': '国富日日收益货币A',
#   'kind': '货币型',
#   'fullcode': 'GUOFURIRISHOUYIHUOBIA'},
#  {'id': '000204',
#   'code': 'GFRRSYHBB',
#   'name': '国富日日收益货币B',
#   'kind': '货币型',
#   'fullcode': 'GUOFURIRISHOUYIHUOBIB'},
#  {'id': '000205',
#   'code': 'YFDTZJXYZZQA',
#   'name': '易方达投资级信用债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'YIFANGDATOUZIJIXINYONGZHAIZHAIQUANA'},
#  {'id': '000206',
#   'code': 'YFDTZJXYZZQC',
#   'name': '易方达投资级信用债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'YIFANGDATOUZIJIXINYONGZHAIZHAIQUANC'},
#  {'id': '000207',
#   'code': 'JXSZZQZQA',
#   'name': '建信双债增强债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'JIANXINSHUANGZHAIZENGQIANGZHAIQUANA'},
#  {'id': '000208',
#   'code': 'JXSZZQZQC',
#   'name': '建信双债增强债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'JIANXINSHUANGZHAIZENGQIANGZHAIQUANC'},
#  {'id': '000209',
#   'code': 'XCXXCYHHA',
#   'name': '信诚新兴产业混合A',
#   'kind': '混合型-偏股',
#   'fullcode': 'XINCHENGXINXINGCHANYEHUNHEA'},
#  {'id': '000210',
#   'code': 'GDXJBHBA',
#   'name': '光大现金宝货币A',
#   'kind': '货币型',
#   'fullcode': 'GUANGDAXIANJINBAOHUOBIA'},
#  {'id': '000211',
#   'code': 'GDXJBHBB',
#   'name': '光大现金宝货币B',
#   'kind': '货币型',
#   'fullcode': 'GUANGDAXIANJINBAOHUOBIB'},
#  {'id': '000212',
#   'code': 'TXXYDQKFA',
#   'name': '泰信鑫益定期开放A',
#   'kind': '债券型-长债',
#   'fullcode': 'TAIXINXINYIDINGQIKAIFANGA'},
#  {'id': '000213',
#   'code': 'TXXYDQKFC',
#   'name': '泰信鑫益定期开放C',
#   'kind': '债券型-长债',
#   'fullcode': 'TAIXINXINYIDINGQIKAIFANGC'},
#  {'id': '000214',
#   'code': 'GFCZYXHH',
#   'name': '广发成长优选混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUANGFACHENGZHANGYOUXUANHUNHE'},
#  {'id': '000215',
#   'code': 'GFQSYXLHPZHHA',
#   'name': '广发趋势优选灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUANGFAQUSHIYOUXUANLINGHUOPEIZHIHUNHEA'},
#  {'id': '000216',
#   'code': 'HAHJYETFLJA',
#   'name': '华安黄金易ETF联接A',
#   'kind': '商品（不含QDII）',
#   'fullcode': 'HUAANHUANGJINYIETFLIANJIEA'},
#  {'id': '000217',
#   'code': 'HAHJYETFLJC',
#   'name': '华安黄金易ETF联接C',
#   'kind': '商品（不含QDII）',
#   'fullcode': 'HUAANHUANGJINYIETFLIANJIEC'},
#  {'id': '000218',
#   'code': 'GTHJETFLJA',
#   'name': '国泰黄金ETF联接A',
#   'kind': '商品（不含QDII）',
#   'fullcode': 'GUOTAIHUANGJINETFLIANJIEA'},
#  {'id': '000219',
#   'code': 'BSYYHH',
#   'name': '博时裕益混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'BOSHIYUYIHUNHE'},
#  {'id': '000220',
#   'code': 'FGYLBJHYHHA',
#   'name': '富国医疗保健行业混合A',
#   'kind': '混合型-偏股',
#   'fullcode': 'FUGUOYILIAOBAOJIANHANGYEHUNHEA'},
#  {'id': '000221',
#   'code': 'HTFNNLDKZA',
#   'name': '汇添富年年利定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUITIANFUNIANNIANLIDINGKAIZHAIA'},
#  {'id': '000222',
#   'code': 'HTFNNLDKZC',
#   'name': '汇添富年年利定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'HUITIANFUNIANNIANLIDINGKAIZHAIC'},
#  {'id': '000227',
#   'code': 'HANNHZQA',
#   'name': '华安年年红债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUAANNIANNIANHONGZHAIQUANA'},
#  {'id': '000235',
#   'code': 'NAWGSYYNDKZ',
#   'name': '诺安稳固收益一年定开债',
#   'kind': '债券型-长债',
#   'fullcode': 'NUOANWENGUSHOUYIYINIANDINGKAIZHAI'},
#  {'id': '000236',
#   'code': 'GYYYXDQZFZQA',
#   'name': '工银月月薪定期支付债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'GONGYINYUEYUEXINDINGQIZHIFUZHAIQUANA'},
#  {'id': '000239',
#   'code': 'HANNYDKZA',
#   'name': '华安年年盈定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUAANNIANNIANYINGDINGKAIZHAIA'},
#  {'id': '000240',
#   'code': 'HANNYDKZC',
#   'name': '华安年年盈定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'HUAANNIANNIANYINGDINGKAIZHAIC'},
#  {'id': '000241',
#   'code': 'BYHXYSHHC',
#   'name': '宝盈核心优势混合C',
#   'kind': '混合型-灵活',
#   'fullcode': 'BAOYINGHEXINYOUSHIHUNHEC'},
#  {'id': '000242',
#   'code': 'JSCCCLJXLHPZHH',
#   'name': '景顺长城策略精选灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'JINGSHUNCHANGCHENGCELUEJINGXUANLINGHUOPEIZHIHUNHE'},
#  {'id': '000244',
#   'code': 'THWLDQKFA',
#   'name': '天弘稳利定期开放A',
#   'kind': '债券型-长债',
#   'fullcode': 'TIANHONGWENLIDINGQIKAIFANGA'},
#  {'id': '000245',
#   'code': 'THWLDQKFB',
#   'name': '天弘稳利定期开放B',
#   'kind': '债券型-长债',
#   'fullcode': 'TIANHONGWENLIDINGQIKAIFANGB'},
#  {'id': '000246',
#   'code': 'BSYYXDQZFZQ',
#   'name': '博时月月薪定期支付债券',
#   'kind': '债券型-长债',
#   'fullcode': 'BOSHIYUEYUEXINDINGQIZHIFUZHAIQUAN'},
#  {'id': '000248',
#   'code': 'HTFZZZYXFETFLJA',
#   'name': '汇添富中证主要消费ETF联接A',
#   'kind': '指数型-股票',
#   'fullcode': 'HUITIANFUZHONGZHENGZHUYAOXIAOFEIETFLIANJIEA'},
#  {'id': '000251',
#   'code': 'GYJRDCHHA',
#   'name': '工银金融地产混合A',
#   'kind': '混合型-偏股',
#   'fullcode': 'GONGYINJINRONGDICHANHUNHEA'},
#  {'id': '000252',
#   'code': 'JSCCJXXYCZZQA',
#   'name': '景顺长城景兴信用纯债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'JINGSHUNCHANGCHENGJINGXINGXINYONGCHUNZHAIZHAIQUANA'},
#  {'id': '000253',
#   'code': 'JSCCJXXYCZZQC',
#   'name': '景顺长城景兴信用纯债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'JINGSHUNCHANGCHENGJINGXINGXINYONGCHUNZHAIZHAIQUANC'},
#  {'id': '000254',
#   'code': 'CCDKZA',
#   'name': '长城定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'CHANGCHENGDINGKAIZHAIA'},
#  {'id': '000255',
#   'code': 'CCDKZC',
#   'name': '长城定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'CHANGCHENGDINGKAIZHAIC'},
#  {'id': '000256',
#   'code': 'STMGHLHBHHA',
#   'name': '上投摩根红利回报混合A',
#   'kind': '混合型-偏债',
#   'fullcode': 'SHANGTOUMOGENHONGLIHUIBAOHUNHEA'},
#  {'id': '000259',
#   'code': 'NYQJSYHH',
#   'name': '农银区间收益混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'NONGYINQUJIANSHOUYIHUNHE'},
#  {'id': '000263',
#   'code': 'GYXXCYHHA',
#   'name': '工银信息产业混合A',
#   'kind': '混合型-偏股',
#   'fullcode': 'GONGYINXINXICHANYEHUNHEA'},
#  {'id': '000264',
#   'code': 'BSNXZZHHA',
#   'name': '博时内需增长混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'BOSHINEIXUZENGZHANGHUNHEA'},
#  {'id': '000265',
#   'code': 'YFDHJTL1NDKZA',
#   'name': '易方达恒久添利1年定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'YIFANGDAHENGJIUTIANLI1NIANDINGKAIZHAIA'},
#  {'id': '000266',
#   'code': 'YFDHJTL1NDKZC',
#   'name': '易方达恒久添利1年定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'YIFANGDAHENGJIUTIANLI1NIANDINGKAIZHAIC'},
#  {'id': '000267',
#   'code': 'GFJLYNDKZA',
#   'name': '广发集利一年定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'GUANGFAJILIYINIANDINGKAIZHAIA'},
#  {'id': '000268',
#   'code': 'GFJLYNDKZC',
#   'name': '广发集利一年定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'GUANGFAJILIYINIANDINGKAIZHAIC'},
#  {'id': '000270',
#   'code': 'JXLHPZHH',
#   'name': '建信灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'JIANXINLINGHUOPEIZHIHUNHE'},
#  {'id': '000271',
#   'code': 'ZYDKZA',
#   'name': '中邮定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'ZHONGYOUDINGKAIZHAIA'},
#  {'id': '000272',
#   'code': 'ZYDKZC',
#   'name': '中邮定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'ZHONGYOUDINGKAIZHAIC'},
#  {'id': '000273',
#   'code': 'HRYDAXLHPZHHA',
#   'name': '华润元大安鑫灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUARUNYUANDAANXINLINGHUOPEIZHIHUNHEA'},
#  {'id': '000274',
#   'code': 'GFYTZGSYZQDIIA',
#   'name': '广发亚太中高收益债(QDII)A',
#   'kind': 'QDII',
#   'fullcode': 'GUANGFAYATAIZHONGGAOSHOUYIZHAIQDIIA'},
#  {'id': '000275',
#   'code': 'GFYTZGSYZMYXHQDIIA',
#   'name': '广发亚太中高收益债美元现汇(QDII)A',
#   'kind': 'QDII',
#   'fullcode': 'GUANGFAYATAIZHONGGAOSHOUYIZHAIMEIYUANXIANHUIQDIIA'},
#  {'id': '000277',
#   'code': 'BSSYXDQZFZQ',
#   'name': '博时双月薪定期支付债券',
#   'kind': '债券型-长债',
#   'fullcode': 'BOSHISHUANGYUEXINDINGQIZHIFUZHAIQUAN'},
#  {'id': '000279',
#   'code': 'HSHLYXHH',
#   'name': '华商红利优选混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUASHANGHONGLIYOUXUANHUNHE'},
#  {'id': '000286',
#   'code': 'YHXYJJHZQA',
#   'name': '银华信用季季红债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'YINHUAXINYONGJIJIHONGZHAIQUANA'},
#  {'id': '000289',
#   'code': 'PHFTDKZA',
#   'name': '鹏华丰泰定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'PENGHUAFENGTAIDINGKAIZHAIA'},
#  {'id': '000290',
#   'code': 'PHQQGSYZQDII',
#   'name': '鹏华全球高收益债(QDII)',
#   'kind': 'QDII',
#   'fullcode': 'PENGHUAQUANQIUGAOSHOUYIZHAIQDII'},
#  {'id': '000294',
#   'code': 'HASTYXHH',
#   'name': '华安生态优先混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUAANSHENGTAIYOUXIANHUNHE'},
#  {'id': '000295',
#   'code': 'PHFSDKZA',
#   'name': '鹏华丰实定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'PENGHUAFENGSHIDINGKAIZHAIA'},
#  {'id': '000296',
#   'code': 'PHFSDKZB',
#   'name': '鹏华丰实定开债B',
#   'kind': '债券型-长债',
#   'fullcode': 'PENGHUAFENGSHIDINGKAIZHAIB'},
#  {'id': '000297',
#   'code': 'PHKZZZQA',
#   'name': '鹏华可转债债券A',
#   'kind': '债券型-可转债',
#   'fullcode': 'PENGHUAKEZHUANZHAIZHAIQUANA'},
#  {'id': '000298',
#   'code': 'ZHCZZQA',
#   'name': '中海纯债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'ZHONGHAICHUNZHAIZHAIQUANA'},
#  {'id': '000299',
#   'code': 'ZHCZZQC',
#   'name': '中海纯债债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'ZHONGHAICHUNZHAIZHAIQUANC'},
#  {'id': '000300',
#   'code': 'DBDLHBA',
#   'name': '德邦德利货币A',
#   'kind': '货币型',
#   'fullcode': 'DEBANGDELIHUOBIA'},
#  {'id': '000301',
#   'code': 'DBDLHBB',
#   'name': '德邦德利货币B',
#   'kind': '货币型',
#   'fullcode': 'DEBANGDELIHUOBIB'},
#  {'id': '000305',
#   'code': 'ZYZGDJA',
#   'name': '中银中高等级A',
#   'kind': '债券型-长债',
#   'fullcode': 'ZHONGYINZHONGGAODENGJIA'},
#  {'id': '000306',
#   'code': 'THHLZQ',
#   'name': '天弘弘利债券',
#   'kind': '债券型-混合债',
#   'fullcode': 'TIANHONGHONGLIZHAIQUAN'},
#  {'id': '000307',
#   'code': 'YFDHJETFLJA',
#   'name': '易方达黄金ETF联接A',
#   'kind': '商品（不含QDII）',
#   'fullcode': 'YIFANGDAHUANGJINETFLIANJIEA'},
#  {'id': '000308',
#   'code': 'JXCXZGHH',
#   'name': '建信创新中国混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'JIANXINCHUANGXINZHONGGUOHUNHE'},
#  {'id': '000309',
#   'code': 'DMPZSHJXGP',
#   'name': '大摩品质生活精选股票',
#   'kind': '股票型',
#   'fullcode': 'DAMOPINZHISHENGHUOJINGXUANGUPIAO'},
#  {'id': '000310',
#   'code': 'AXYLXYA',
#   'name': '安信永利信用A',
#   'kind': '债券型-长债',
#   'fullcode': 'ANXINYONGLIXINYONGA'},
#  {'id': '000311',
#   'code': 'JSCCHS300ZSZQ',
#   'name': '景顺长城沪深300指数增强',
#   'kind': '指数型-股票',
#   'fullcode': 'JINGSHUNCHANGCHENGHUSHEN300ZHISHUZENGQIANG'},
#  {'id': '000312',
#   'code': 'HAHS300ZQA',
#   'name': '华安沪深300增强A',
#   'kind': '指数型-股票',
#   'fullcode': 'HUAANHUSHEN300ZENGQIANGA'},
#  {'id': '000313',
#   'code': 'HAHS300ZQC',
#   'name': '华安沪深300增强C',
#   'kind': '指数型-股票',
#   'fullcode': 'HUAANHUSHEN300ZENGQIANGC'},
#  {'id': '000314',
#   'code': 'ZSRFLHPZHHFQSA',
#   'name': '招商瑞丰灵活配置混合发起式A',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHAOSHANGRUIFENGLINGHUOPEIZHIHUNHEFAQISHIA'},
#  {'id': '000319',
#   'code': 'TDTLZQA',
#   'name': '泰达淘利债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'TAIDATAOLIZHAIQUANA'},
#  {'id': '000320',
#   'code': 'TDTLZQC',
#   'name': '泰达淘利债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'TAIDATAOLIZHAIQUANC'},
#  {'id': '000322',
#   'code': 'NYHLJHZQA',
#   'name': '农银汇理金汇债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'NONGYINHUILIJINHUIZHAIQUANA'},
#  {'id': '000324',
#   'code': 'HRYDXJSYHBA',
#   'name': '华润元大现金收益货币A',
#   'kind': '货币型',
#   'fullcode': 'HUARUNYUANDAXIANJINSHOUYIHUOBIA'},
#  {'id': '000325',
#   'code': 'HRYDXJSYHBB',
#   'name': '华润元大现金收益货币B',
#   'kind': '货币型',
#   'fullcode': 'HUARUNYUANDAXIANJINSHOUYIHUOBIB'},
#  {'id': '000326',
#   'code': 'NFZXPCZGP',
#   'name': '南方中小盘成长股票',
#   'kind': '股票型',
#   'fullcode': 'NANFANGZHONGXIAOPANCHENGZHANGGUPIAO'},
#  {'id': '000327',
#   'code': 'NFXLCHH',
#   'name': '南方新蓝筹混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'NANFANGXINLANCHOUHUNHE'},
#  {'id': '000328',
#   'code': 'STMGZXDLLHPZHH',
#   'name': '上投摩根转型动力灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'SHANGTOUMOGENZHUANXINGDONGLILINGHUOPEIZHIHUNHE'},
#  {'id': '000329',
#   'code': 'PHFRDKZ',
#   'name': '鹏华丰饶定开债',
#   'kind': '债券型-长债',
#   'fullcode': 'PENGHUAFENGRAODINGKAIZHAI'},
#  {'id': '000330',
#   'code': 'HTFXJBHBA',
#   'name': '汇添富现金宝货币A',
#   'kind': '货币型',
#   'fullcode': 'HUITIANFUXIANJINBAOHUOBIA'},
#  {'id': '000331',
#   'code': 'ZJHBA',
#   'name': '中加货币A',
#   'kind': '货币型',
#   'fullcode': 'ZHONGJIAHUOBIA'},
#  {'id': '000332',
#   'code': 'ZJHBC',
#   'name': '中加货币C',
#   'kind': '货币型',
#   'fullcode': 'ZHONGJIAHUOBIC'},
#  {'id': '000333',
#   'code': 'CCWGSYZQA',
#   'name': '长城稳固收益债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'CHANGCHENGWENGUSHOUYIZHAIQUANA'},
#  {'id': '000334',
#   'code': 'CCWGSYZQC',
#   'name': '长城稳固收益债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'CHANGCHENGWENGUSHOUYIZHAIQUANC'},
#  {'id': '000335',
#   'code': 'AXYLXYC',
#   'name': '安信永利信用C',
#   'kind': '债券型-长债',
#   'fullcode': 'ANXINYONGLIXINYONGC'},
#  {'id': '000336',
#   'code': 'NYYJJXHH',
#   'name': '农银研究精选混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'NONGYINYANJIUJINGXUANHUNHE'},
#  {'id': '000338',
#   'code': 'PHSZBLZQ',
#   'name': '鹏华双债保利债券',
#   'kind': '债券型-混合债',
#   'fullcode': 'PENGHUASHUANGZHAIBAOLIZHAIQUAN'},
#  {'id': '000339',
#   'code': 'CCYLBJHH',
#   'name': '长城医疗保健混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'CHANGCHENGYILIAOBAOJIANHUNHE'},
#  {'id': '000341',
#   'code': 'JSXXSCC2QDII',
#   'name': '嘉实新兴市场C2(QDII)',
#   'kind': 'QDII',
#   'fullcode': 'JIASHIXINXINGSHICHANGC2QDII'},
#  {'id': '000342',
#   'code': 'JSXXSCA1QDII',
#   'name': '嘉实新兴市场A1(QDII)',
#   'kind': 'QDII',
#   'fullcode': 'JIASHIXINXINGSHICHANGA1QDII'},
#  {'id': '000343',
#   'code': 'HXCFBHBA',
#   'name': '华夏财富宝货币A',
#   'kind': '货币型',
#   'fullcode': 'HUAXIACAIFUBAOHUOBIA'},
#  {'id': '000345',
#   'code': 'PHFRDKZ',
#   'name': '鹏华丰融定开债',
#   'kind': '债券型-长债',
#   'fullcode': 'PENGHUAFENGRONGDINGKAIZHAI'},
#  {'id': '000346',
#   'code': 'JXAXHB6GYDKA',
#   'name': '建信安心回报6个月定开A',
#   'kind': '债券型-长债',
#   'fullcode': 'JIANXINANXINHUIBAO6GEYUEDINGKAIA'},
#  {'id': '000347',
#   'code': 'JXAXHB6GYDKC',
#   'name': '建信安心回报6个月定开C',
#   'kind': '债券型-长债',
#   'fullcode': 'JIANXINANXINHUIBAO6GEYUEDINGKAIC'},
#  {'id': '000351',
#   'code': 'GFHFDQZQA',
#   'name': '国富恒丰定期债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'GUOFUHENGFENGDINGQIZHAIQUANA'},
#  {'id': '000352',
#   'code': 'GFHFDQZQC',
#   'name': '国富恒丰定期债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'GUOFUHENGFENGDINGQIZHAIQUANC'},
#  {'id': '000354',
#   'code': 'CSCZHZTHH',
#   'name': '长盛城镇化主题混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'CHANGSHENGCHENGZHENHUAZHUTIHUNHE'},
#  {'id': '000355',
#   'code': 'NFFYXYZQZQA',
#   'name': '南方丰元信用增强债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'NANFANGFENGYUANXINYONGZENGQIANGZHAIQUANA'},
#  {'id': '000356',
#   'code': 'NFFYXYZQZQC',
#   'name': '南方丰元信用增强债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'NANFANGFENGYUANXINYONGZENGQIANGZHAIQUANC'},
#  {'id': '000359',
#   'code': 'YFDYLCHBA',
#   'name': '易方达易理财货币A',
#   'kind': '货币型',
#   'fullcode': 'YIFANGDAYILICAIHUOBIA'},
#  {'id': '000362',
#   'code': 'GTJXJZYSHHA',
#   'name': '国泰聚信价值优势混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOTAIJUXINJIAZHIYOUSHIHUNHEA'},
#  {'id': '000363',
#   'code': 'GTJXJZYSHHC',
#   'name': '国泰聚信价值优势混合C',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOTAIJUXINJIAZHIYOUSHIHUNHEC'},
#  {'id': '000366',
#   'code': 'HTFTFTHBA',
#   'name': '汇添富添富通货币A',
#   'kind': '货币型',
#   'fullcode': 'HUITIANFUTIANFUTONGHUOBIA'},
#  {'id': '000367',
#   'code': 'GTAKDQZFHHA',
#   'name': '国泰安康定期支付混合A',
#   'kind': '混合型-偏债',
#   'fullcode': 'GUOTAIANKANGDINGQIZHIFUHUNHEA'},
#  {'id': '000368',
#   'code': 'HTFHS300AZZS',
#   'name': '汇添富沪深300安中指数',
#   'kind': '指数型-股票',
#   'fullcode': 'HUITIANFUHUSHEN300ANZHONGZHISHU'},
#  {'id': '000369',
#   'code': 'GFQQYLBJQDII',
#   'name': '广发全球医疗保健(QDII)',
#   'kind': 'QDII',
#   'fullcode': 'GUANGFAQUANQIUYILIAOBAOJIANQDII'},
#  {'id': '000370',
#   'code': 'GFQQYLBJMY',
#   'name': '广发全球医疗保健美元',
#   'kind': 'QDII',
#   'fullcode': 'GUANGFAQUANQIUYILIAOBAOJIANMEIYUAN'},
#  {'id': '000371',
#   'code': 'MSJYXJBHBA',
#   'name': '民生加银现金宝货币A',
#   'kind': '货币型',
#   'fullcode': 'MINSHENGJIAYINXIANJINBAOHUOBIA'},
#  {'id': '000372',
#   'code': 'ZYHLBNDKZ',
#   'name': '中银惠利半年定开债',
#   'kind': '债券型-长债',
#   'fullcode': 'ZHONGYINHUILIBANNIANDINGKAIZHAI'},
#  {'id': '000373',
#   'code': 'HAZZXFYYETFLJA',
#   'name': '华安中证细分医药ETF联接A',
#   'kind': '指数型-股票',
#   'fullcode': 'HUAANZHONGZHENGXIFENYIYAOETFLIANJIEA'},
#  {'id': '000376',
#   'code': 'HAZZXFYYETFLJC',
#   'name': '华安中证细分医药ETF联接C',
#   'kind': '指数型-股票',
#   'fullcode': 'HUAANZHONGZHENGXIFENYIYAOETFLIANJIEC'},
#  {'id': '000377',
#   'code': 'STMGSZZLZQA',
#   'name': '上投摩根双债增利债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'SHANGTOUMOGENSHUANGZHAIZENGLIZHAIQUANA'},
#  {'id': '000378',
#   'code': 'STMGSZZLZQC',
#   'name': '上投摩根双债增利债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'SHANGTOUMOGENSHUANGZHAIZENGLIZHAIQUANC'},
#  {'id': '000379',
#   'code': 'PARZLHBA',
#   'name': '平安日增利货币A',
#   'kind': '货币型',
#   'fullcode': 'PINGANRIZENGLIHUOBIA'},
#  {'id': '000380',
#   'code': 'JSCCJYHBA',
#   'name': '景顺长城景益货币A',
#   'kind': '货币型',
#   'fullcode': 'JINGSHUNCHANGCHENGJINGYIHUOBIA'},
#  {'id': '000381',
#   'code': 'JSCCJYHBB',
#   'name': '景顺长城景益货币B',
#   'kind': '货币型',
#   'fullcode': 'JINGSHUNCHANGCHENGJINGYIHUOBIB'},
#  {'id': '000385',
#   'code': 'JSCCJYSLZQA',
#   'name': '景顺长城景颐双利债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'JINGSHUNCHANGCHENGJINGYISHUANGLIZHAIQUANA'},
#  {'id': '000386',
#   'code': 'JSCCJYSLZQC',
#   'name': '景顺长城景颐双利债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'JINGSHUNCHANGCHENGJINGYISHUANGLIZHAIQUANC'},
#  {'id': '000389',
#   'code': 'GFTTHHBA',
#   'name': '广发天天红货币A',
#   'kind': '货币型',
#   'fullcode': 'GUANGFATIANTIANHONGHUOBIA'},
#  {'id': '000390',
#   'code': 'HSYSHYHH',
#   'name': '华商优势行业混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUASHANGYOUSHIHANGYEHUNHE'},
#  {'id': '000394',
#   'code': 'RTTYDRZQA',
#   'name': '融通通源短融债券A',
#   'kind': '债券型-中短债',
#   'fullcode': 'RONGTONGTONGYUANDUANRONGZHAIQUANA'},
#  {'id': '000395',
#   'code': 'HTFAXZGZQA',
#   'name': '汇添富安心中国债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUITIANFUANXINZHONGGUOZHAIQUANA'},
#  {'id': '000396',
#   'code': 'HTFAXZGZQC',
#   'name': '汇添富安心中国债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'HUITIANFUANXINZHONGGUOZHAIQUANC'},
#  {'id': '000397',
#   'code': 'HTFQEBHB',
#   'name': '汇添富全额宝货币',
#   'kind': '货币型',
#   'fullcode': 'HUITIANFUQUANEBAOHUOBI'},
#  {'id': '000398',
#   'code': 'HFLHPZHH',
#   'name': '华富灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUAFULINGHUOPEIZHIHUNHE'},
#  {'id': '000402',
#   'code': 'GYCZZQA',
#   'name': '工银纯债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'GONGYINCHUNZHAIZHAIQUANA'},
#  {'id': '000403',
#   'code': 'GYCZZQB',
#   'name': '工银纯债债券B',
#   'kind': '债券型-长债',
#   'fullcode': 'GONGYINCHUNZHAIZHAIQUANB'},
#  {'id': '000404',
#   'code': 'YFDXXCZLHPZ',
#   'name': '易方达新兴成长灵活配置',
#   'kind': '混合型-灵活',
#   'fullcode': 'YIFANGDAXINXINGCHENGZHANGLINGHUOPEIZHI'},
#  {'id': '000406',
#   'code': 'HTFSLZQZQA',
#   'name': '汇添富双利增强债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'HUITIANFUSHUANGLIZENGQIANGZHAIQUANA'},
#  {'id': '000407',
#   'code': 'HTFSLZQZQC',
#   'name': '汇添富双利增强债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'HUITIANFUSHUANGLIZENGQIANGZHAIQUANC'},
#  {'id': '000408',
#   'code': 'MSJYCZHHHA',
#   'name': '民生加银城镇化混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'MINSHENGJIAYINCHENGZHENHUAHUNHEA'},
#  {'id': '000409',
#   'code': 'PHHBCYGP',
#   'name': '鹏华环保产业股票',
#   'kind': '股票型',
#   'fullcode': 'PENGHUAHUANBAOCHANYEGUPIAO'},
#  {'id': '000410',
#   'code': 'YMFWLXHH',
#   'name': '益民服务领先混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'YIMINFUWULINGXIANHUNHE'},
#  {'id': '000411',
#   'code': 'JSCCYZCZGP',
#   'name': '景顺长城优质成长股票',
#   'kind': '股票型',
#   'fullcode': 'JINGSHUNCHANGCHENGYOUZHICHENGZHANGGUPIAO'},
#  {'id': '000414',
#   'code': 'JSJDSYCLDQHH',
#   'name': '嘉实绝对收益策略定期混合',
#   'kind': '混合型-平衡',
#   'fullcode': 'JIASHIJUEDUISHOUYICELUEDINGQIHUNHE'},
#  {'id': '000415',
#   'code': 'DMTL18GYDKZA',
#   'name': '大摩添利18个月定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'DAMOTIANLI18GEYUEDINGKAIZHAIA'},
#  {'id': '000416',
#   'code': 'DMTL18GYDKZC',
#   'name': '大摩添利18个月定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'DAMOTIANLI18GEYUEDINGKAIZHAIC'},
#  {'id': '000417',
#   'code': 'GLAXJXHH',
#   'name': '国联安新精选混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOLIANANXINJINGXUANHUNHE'},
#  {'id': '000418',
#   'code': 'JSCCCZZXGP',
#   'name': '景顺长城成长之星股票',
#   'kind': '股票型',
#   'fullcode': 'JINGSHUNCHANGCHENGCHENGZHANGZHIXINGGUPIAO'},
#  {'id': '000419',
#   'code': 'DMYZXJCZA',
#   'name': '大摩优质信价纯债A',
#   'kind': '债券型-长债',
#   'fullcode': 'DAMOYOUZHIXINJIACHUNZHAIA'},
#  {'id': '000420',
#   'code': 'DMYZXJCZC',
#   'name': '大摩优质信价纯债C',
#   'kind': '债券型-长债',
#   'fullcode': 'DAMOYOUZHIXINJIACHUNZHAIC'},
#  {'id': '000423',
#   'code': 'QHKYSJQDHHA',
#   'name': '前海开源事件驱动混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'QIANHAIKAIYUANSHIJIANQUDONGHUNHEA'},
#  {'id': '000424',
#   'code': 'CSTLBHBA',
#   'name': '长盛添利宝货币A',
#   'kind': '货币型',
#   'fullcode': 'CHANGSHENGTIANLIBAOHUOBIA'},
#  {'id': '000425',
#   'code': 'CSTLBHBB',
#   'name': '长盛添利宝货币B',
#   'kind': '货币型',
#   'fullcode': 'CHANGSHENGTIANLIBAOHUOBIB'},
#  {'id': '000431',
#   'code': 'PHPPCCHH',
#   'name': '鹏华品牌传承混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'PENGHUAPINPAICHUANCHENGHUNHE'},
#  {'id': '000432',
#   'code': 'ZYYXQYHH',
#   'name': '中银优秀企业混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'ZHONGYINYOUXIUQIYEHUNHE'},
#  {'id': '000433',
#   'code': 'AXXFYXHHA',
#   'name': '安信鑫发优选混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'ANXINXINFAYOUXUANHUNHEA'},
#  {'id': '000434',
#   'code': 'XHYNBHBA',
#   'name': '新华壹诺宝货币A',
#   'kind': '货币型',
#   'fullcode': 'XINHUAYINUOBAOHUOBIA'},
#  {'id': '000436',
#   'code': 'YFDYHDKHHFQS',
#   'name': '易方达裕惠定开混合发起式',
#   'kind': '混合型-偏债',
#   'fullcode': 'YIFANGDAYUHUIDINGKAIHUNHEFAQISHI'},
#  {'id': '000439',
#   'code': 'GJXYHB',
#   'name': '国金鑫盈货币',
#   'kind': '货币型',
#   'fullcode': 'GUOJINXINYINGHUOBI'},
#  {'id': '000452',
#   'code': 'NFYYBJLHPZHH',
#   'name': '南方医药保健灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'NANFANGYIYAOBAOJIANLINGHUOPEIZHIHUNHE'},
#  {'id': '000457',
#   'code': 'STMGHXCZGP',
#   'name': '上投摩根核心成长股票',
#   'kind': '股票型',
#   'fullcode': 'SHANGTOUMOGENHEXINCHENGZHANGGUPIAO'},
#  {'id': '000458',
#   'code': 'YDLXHBHHFQS',
#   'name': '英大领先回报混合发起式',
#   'kind': '混合型-偏股',
#   'fullcode': 'YINGDALINGXIANHUIBAOHUNHEFAQISHI'},
#  {'id': '000459',
#   'code': 'YDLXHBHHFQS',
#   'name': '英大领先回报混合发起式(后端)',
#   'kind': '混合型-偏股',
#   'fullcode': 'YINGDALINGXIANHUIBAOHUNHEFAQISHI'},
#  {'id': '000462',
#   'code': 'NYZTLDHH',
#   'name': '农银主题轮动混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'NONGYINZHUTILUNDONGHUNHE'},
#  {'id': '000463',
#   'code': 'HSSZFLZQA',
#   'name': '华商双债丰利债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'HUASHANGSHUANGZHAIFENGLIZHAIQUANA'},
#  {'id': '000464',
#   'code': 'JSHQBHB',
#   'name': '嘉实活期宝货币',
#   'kind': '货币型',
#   'fullcode': 'JIASHIHUOQIBAOHUOBI'},
#  {'id': '000465',
#   'code': 'JSCCXYXDQZFZQ',
#   'name': '景顺长城鑫月薪定期支付债券',
#   'kind': '债券型-长债',
#   'fullcode': 'JINGSHUNCHANGCHENGXINYUEXINDINGQIZHIFUZHAIQUAN'},
#  {'id': '000466',
#   'code': 'RTTRZQAB',
#   'name': '融通通瑞债券A/B',
#   'kind': '债券型-混合债',
#   'fullcode': 'RONGTONGTONGRUIZHAIQUANAB'},
#  {'id': '000469',
#   'code': 'FGMBQLYNQCZZQ',
#   'name': '富国目标齐利一年期纯债债券',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOMUBIAOQILIYINIANQICHUNZHAIZHAIQUAN'},
#  {'id': '000470',
#   'code': 'FGMBQLYNQCZZQ',
#   'name': '富国目标齐利一年期纯债债券(后端)',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOMUBIAOQILIYINIANQICHUNZHAIZHAIQUAN'},
#  {'id': '000471',
#   'code': 'FGCZFZGP',
#   'name': '富国城镇发展股票',
#   'kind': '股票型',
#   'fullcode': 'FUGUOCHENGZHENFAZHANGUPIAO'},
#  {'id': '000472',
#   'code': 'FGCZFZGP',
#   'name': '富国城镇发展股票(后端)',
#   'kind': '股票型',
#   'fullcode': 'FUGUOCHENGZHENFAZHANGUPIAO'},
#  {'id': '000475',
#   'code': 'GFTTLHBA',
#   'name': '广发天天利货币A',
#   'kind': '货币型',
#   'fullcode': 'GUANGFATIANTIANLIHUOBIA'},
#  {'id': '000476',
#   'code': 'GFTTLHBB',
#   'name': '广发天天利货币B',
#   'kind': '货币型',
#   'fullcode': 'GUANGFATIANTIANLIHUOBIB'},
#  {'id': '000477',
#   'code': 'GFZTLXHH',
#   'name': '广发主题领先混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUANGFAZHUTILINGXIANHUNHE'},
#  {'id': '000478',
#   'code': 'JXZZ500ZSZQA',
#   'name': '建信中证500指数增强A',
#   'kind': '指数型-股票',
#   'fullcode': 'JIANXINZHONGZHENG500ZHISHUZENGQIANGA'},
#  {'id': '000480',
#   'code': 'DFHXDLHH',
#   'name': '东方红新动力混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'DONGFANGHONGXINDONGLIHUNHE'},
#  {'id': '000481',
#   'code': 'HSSZFLZQC',
#   'name': '华商双债丰利债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'HUASHANGSHUANGZHAIFENGLIZHAIQUANC'},
#  {'id': '000483',
#   'code': 'XYHBA',
#   'name': '鑫元货币A',
#   'kind': '货币型',
#   'fullcode': 'XINYUANHUOBIA'},
#  {'id': '000484',
#   'code': 'XYHBB',
#   'name': '鑫元货币B',
#   'kind': '货币型',
#   'fullcode': 'XINYUANHUOBIB'},
#  {'id': '000487',
#   'code': 'JS3GYLCZQA',
#   'name': '嘉实3个月理财债券A',
#   'kind': '理财型',
#   'fullcode': 'JIASHI3GEYUELICAIZHAIQUANA'},
#  {'id': '000488',
#   'code': 'JS3GYLCZQE',
#   'name': '嘉实3个月理财债券E',
#   'kind': '理财型',
#   'fullcode': 'JIASHI3GEYUELICAIZHAIQUANE'},
#  {'id': '000489',
#   'code': 'GDSMHLCZA',
#   'name': '光大岁末红利纯债A',
#   'kind': '债券型-长债',
#   'fullcode': 'GUANGDASUIMOHONGLICHUNZHAIA'},
#  {'id': '000490',
#   'code': 'GDSMHLCZC',
#   'name': '光大岁末红利纯债C',
#   'kind': '债券型-长债',
#   'fullcode': 'GUANGDASUIMOHONGLICHUNZHAIC'},
#  {'id': '000493',
#   'code': 'NFXJTA',
#   'name': '南方现金通A',
#   'kind': '货币型',
#   'fullcode': 'NANFANGXIANJINTONGA'},
#  {'id': '000494',
#   'code': 'NFXJTB',
#   'name': '南方现金通B',
#   'kind': '货币型',
#   'fullcode': 'NANFANGXIANJINTONGB'},
#  {'id': '000495',
#   'code': 'NFXJTC',
#   'name': '南方现金通C',
#   'kind': '货币型',
#   'fullcode': 'NANFANGXIANJINTONGC'},
#  {'id': '000496',
#   'code': 'CACYJXHHA',
#   'name': '长安产业精选混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'CHANGANCHANYEJINGXUANHUNHEA'},
#  {'id': '000497',
#   'code': 'CTCZZQA',
#   'name': '财通纯债债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'CAITONGCHUNZHAIZHAIQUANA'},
#  {'id': '000501',
#   'code': 'HFHF18GYDKZC',
#   'name': '华富恒富18个月定开债C',
#   'kind': '债券型-长债',
#   'fullcode': 'HUAFUHENGFU18GEYUEDINGKAIZHAIC'},
#  {'id': '000502',
#   'code': 'HFHF18GYDKZA',
#   'name': '华富恒富18个月定开债A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUAFUHENGFU18GEYUEDINGKAIZHAIA'},
#  {'id': '000503',
#   'code': 'ZXJTJHZDZA',
#   'name': '中信建投景和中短债A',
#   'kind': '债券型-中短债',
#   'fullcode': 'ZHONGXINJIANTOUJINGHEZHONGDUANZHAIA'},
#  {'id': '000504',
#   'code': 'ZXJTJHZDZC',
#   'name': '中信建投景和中短债C',
#   'kind': '债券型-中短债',
#   'fullcode': 'ZHONGXINJIANTOUJINGHEZHONGDUANZHAIC'},
#  {'id': '000505',
#   'code': 'GSABHBA',
#   'name': '国寿安保货币A',
#   'kind': '货币型',
#   'fullcode': 'GUOSHOUANBAOHUOBIA'},
#  {'id': '000506',
#   'code': 'GSABHBB',
#   'name': '国寿安保货币B',
#   'kind': '货币型',
#   'fullcode': 'GUOSHOUANBAOHUOBIB'},
#  {'id': '000507',
#   'code': 'TDHLHDHHA',
#   'name': '泰达宏利宏达混合A',
#   'kind': '混合型-偏债',
#   'fullcode': 'TAIDAHONGLIHONGDAHUNHEA'},
#  {'id': '000508',
#   'code': 'TDHLHDHHB',
#   'name': '泰达宏利宏达混合B',
#   'kind': '混合型-偏债',
#   'fullcode': 'TAIDAHONGLIHONGDAHUNHEB'},
#  {'id': '000509',
#   'code': 'GFQDZHBA',
#   'name': '广发钱袋子货币A',
#   'kind': '货币型',
#   'fullcode': 'GUANGFAQIANDAIZIHUOBIA'},
#  {'id': '000511',
#   'code': 'GTGCQDLHPZHHA',
#   'name': '国泰国策驱动灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOTAIGUOCEQUDONGLINGHUOPEIZHIHUNHEA'},
#  {'id': '000512',
#   'code': 'GTHS300ZSZQA',
#   'name': '国泰沪深300指数增强A',
#   'kind': '指数型-股票',
#   'fullcode': 'GUOTAIHUSHEN300ZHISHUZENGQIANGA'},
#  {'id': '000513',
#   'code': 'FGGDZZHYGP',
#   'name': '富国高端制造行业股票',
#   'kind': '股票型',
#   'fullcode': 'FUGUOGAODUANZHIZAOHANGYEGUPIAO'},
#  {'id': '000514',
#   'code': 'FGGDZZHYGP',
#   'name': '富国高端制造行业股票(后端)',
#   'kind': '股票型',
#   'fullcode': 'FUGUOGAODUANZHIZAOHANGYEGUPIAO'},
#  {'id': '000516',
#   'code': 'FGXLYNQDQKFZQXA',
#   'name': '富国祥利一年期定期开放债券型A',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOXIANGLIYINIANQIDINGQIKAIFANGZHAIQUANXINGA'},
#  {'id': '000517',
#   'code': 'FGXLYNQDQKFZQXC',
#   'name': '富国祥利一年期定期开放债券型C',
#   'kind': '债券型-长债',
#   'fullcode': 'FUGUOXIANGLIYINIANQIDINGQIKAIFANGZHAIQUANXINGC'},
#  {'id': '000520',
#   'code': 'SYXXJZCZHH',
#   'name': '上银新兴价值成长混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'SHANGYINXINXINGJIAZHICHENGZHANGHUNHE'},
#  {'id': '000521',
#   'code': 'NARXDKZQ',
#   'name': '诺安瑞鑫定开债券',
#   'kind': '债券型-长债',
#   'fullcode': 'NUOANRUIXINDINGKAIZHAIQUAN'},
#  {'id': '000522',
#   'code': 'HRYDXXCMKJHH',
#   'name': '华润元大信息传媒科技混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'HUARUNYUANDAXINXICHUANMEIKEJIHUNHE'},
#  {'id': '000523',
#   'code': 'GTRYYLBJHHA',
#   'name': '国投瑞银医疗保健混合A',
#   'kind': '混合型-灵活',
# ...
#  {'id': '001183',
#   'code': 'NFLTA',
#   'name': '南方利淘A',
#   'kind': '混合型-灵活',
#   'fullcode': 'NANFANGLITAOA'},
#  {'id': '001184',
#   'code': 'YFDXCTLHPZHH',
#   'name': '易方达新常态灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'YIFANGDAXINCHANGTAILINGHUOPEIZHIHUNHE'},
#  {'id': '001185',
#   'code': 'AXDTCLHHA',
#   'name': '安信动态策略混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'ANXINDONGTAICELUEHUNHEA'},
#  {'id': '001186',
#   'code': 'FGWTJKGPA',
#   'name': '富国文体健康股票A',
#   'kind': '股票型',
#   'fullcode': 'FUGUOWENTIJIANKANGGUPIAOA'},
#  {'id': '001188',
#   'code': 'PHGGHLGP',
#   'name': '鹏华改革红利股票',
#   'kind': '股票型',
#   'fullcode': 'PENGHUAGAIGEHONGLIGUPIAO'},
#  {'id': '001189',
#   'code': 'GFJBHHA',
#   'name': '广发聚宝混合A',
#   'kind': '混合型-偏债',
#   'fullcode': 'GUANGFAJUBAOHUNHEA'},
#  {'id': '001190',
#   'code': 'PHHRHHA',
#   'name': '鹏华弘润混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'PENGHUAHONGRUNHUNHEA'},
#  {'id': '001191',
#   'code': 'PHHRHHC',
#   'name': '鹏华弘润混合C',
#   'kind': '混合型-灵活',
#   'fullcode': 'PENGHUAHONGRUNHUNHEC'},
#  {'id': '001192',
#   'code': 'STMGZHQDHH',
#   'name': '上投摩根整合驱动混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'SHANGTOUMOGENZHENGHEQUDONGHUNHE'},
#  {'id': '001193',
#   'code': 'ZJXFSJ',
#   'name': '中金消费升级',
#   'kind': '股票型',
#   'fullcode': 'ZHONGJINXIAOFEISHENGJI'},
#  {'id': '001194',
#   'code': 'JSCCWJHBHHA',
#   'name': '景顺长城稳健回报混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'JINGSHUNCHANGCHENGWENJIANHUIBAOHUNHEA'},
#  {'id': '001195',
#   'code': 'GYNYCYGP',
#   'name': '工银农业产业股票',
#   'kind': '股票型',
#   'fullcode': 'GONGYINNONGYECHANYEGUPIAO'},
#  {'id': '001196',
#   'code': 'DFDXLHPZHHA',
#   'name': '东方鼎新灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'DONGFANGDINGXINLINGHUOPEIZHIHUNHEA'},
#  {'id': '001197',
#   'code': 'CSZXSJZTLHPZHH',
#   'name': '长盛转型升级主题灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'CHANGSHENGZHUANXINGSHENGJIZHUTILINGHUOPEIZHIHUNHE'},
#  {'id': '001198',
#   'code': 'DFHXLHPZHHA',
#   'name': '东方惠新灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'DONGFANGHUIXINLINGHUOPEIZHIHUNHEA'},
#  {'id': '001199',
#   'code': 'CJHXJLZQA',
#   'name': '创金合信聚利债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'CHUANGJINHEXINJULIZHAIQUANA'},
#  {'id': '001200',
#   'code': 'CJHXJLZQC',
#   'name': '创金合信聚利债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'CHUANGJINHEXINJULIZHAIQUANC'},
#  {'id': '001201',
#   'code': 'SWLXAXHBHHA',
#   'name': '申万菱信安鑫回报混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'SHENWANLINGXINANXINHUIBAOHUNHEA'},
#  {'id': '001202',
#   'code': 'DFHLXJXHH',
#   'name': '东方红领先精选混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'DONGFANGHONGLINGXIANJINGXUANHUNHE'},
#  {'id': '001203',
#   'code': 'DFHWJJXHHA',
#   'name': '东方红稳健精选混合A',
#   'kind': '混合型-偏债',
#   'fullcode': 'DONGFANGHONGWENJIANJINGXUANHUNHEA'},
#  {'id': '001204',
#   'code': 'DFHWJJXHHC',
#   'name': '东方红稳健精选混合C',
#   'kind': '混合型-偏债',
#   'fullcode': 'DONGFANGHONGWENJIANJINGXUANHUNHEC'},
#  {'id': '001208',
#   'code': 'NADTJJGPA',
#   'name': '诺安低碳经济股票A',
#   'kind': '股票型',
#   'fullcode': 'NUOANDITANJINGJIGUPIAOA'},
#  {'id': '001209',
#   'code': 'QHKYYDYLHHA',
#   'name': '前海开源一带一路混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'QIANHAIKAIYUANYIDAIYILUHUNHEA'},
#  {'id': '001210',
#   'code': 'THHLWHH',
#   'name': '天弘互联网混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'TIANHONGHULIANWANGHUNHE'},
#  {'id': '001211',
#   'code': 'ZOGQBHBA',
#   'name': '中欧滚钱宝货币A',
#   'kind': '货币型',
#   'fullcode': 'ZHONGOUGUNQIANBAOHUOBIA'},
#  {'id': '001212',
#   'code': 'HRYDWJZQA',
#   'name': '华润元大稳健债券A',
#   'kind': '债券型-长债',
#   'fullcode': 'HUARUNYUANDAWENJIANZHAIQUANA'},
#  {'id': '001213',
#   'code': 'HRYDWJZQC',
#   'name': '华润元大稳健债券C',
#   'kind': '债券型-长债',
#   'fullcode': 'HUARUNYUANDAWENJIANZHAIQUANC'},
#  {'id': '001214',
#   'code': 'HTBRZZ500ETFLJA',
#   'name': '华泰柏瑞中证500ETF联接A',
#   'kind': '指数型-股票',
#   'fullcode': 'HUATAIBAIRUIZHONGZHENG500ETFLIANJIEA'},
#  {'id': '001215',
#   'code': 'BSHGSYZQYJJA',
#   'name': '博时沪港深优质企业基金A',
#   'kind': '混合型-灵活',
#   'fullcode': 'BOSHIHUGANGSHENYOUZHIQIYEJIJINA'},
#  {'id': '001216',
#   'code': 'YFDXSYHHA',
#   'name': '易方达新收益混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'YIFANGDAXINSHOUYIHUNHEA'},
#  {'id': '001217',
#   'code': 'YFDXSYHHC',
#   'name': '易方达新收益混合C',
#   'kind': '混合型-灵活',
#   'fullcode': 'YIFANGDAXINSHOUYIHUNHEC'},
#  {'id': '001218',
#   'code': 'GTRYJXSYHH',
#   'name': '国投瑞银精选收益混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOTOURUIYINJINGXUANSHOUYIHUNHE'},
#  {'id': '001219',
#   'code': 'STMGDTDYZHH',
#   'name': '上投摩根动态多因子混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'SHANGTOUMOGENDONGTAIDUOYINZIHUNHE'},
#  {'id': '001220',
#   'code': 'MSJYYJJXHH',
#   'name': '民生加银研究精选混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'MINSHENGJIAYINYANJIUJINGXUANHUNHE'},
#  {'id': '001222',
#   'code': 'PHWYCZHH',
#   'name': '鹏华外延成长混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'PENGHUAWAIYANCHENGZHANGHUNHE'},
#  {'id': '001223',
#   'code': 'PHWHCMYLGP',
#   'name': '鹏华文化传媒娱乐股票',
#   'kind': '股票型',
#   'fullcode': 'PENGHUAWENHUACHUANMEIYULEGUPIAO'},
#  {'id': '001224',
#   'code': 'ZYXSLLHPZHH',
#   'name': '中邮新思路灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHONGYOUXINSILULINGHUOPEIZHIHUNHE'},
#  {'id': '001225',
#   'code': 'ZYQSJXLHPZHH',
#   'name': '中邮趋势精选灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHONGYOUQUSHIJINGXUANLINGHUOPEIZHIHUNHE'},
#  {'id': '001226',
#   'code': 'ZYWJTLLHPZHH',
#   'name': '中邮稳健添利灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHONGYOUWENJIANTIANLILINGHUOPEIZHIHUNHE'},
#  {'id': '001227',
#   'code': 'ZYXXCYLHPZHH',
#   'name': '中邮信息产业灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHONGYOUXINXICHANYELINGHUOPEIZHIHUNHE'},
#  {'id': '001228',
#   'code': 'GLAXXLHPZHHA',
#   'name': '国联安鑫享灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOLIANANXINXIANGLINGHUOPEIZHIHUNHEA'},
#  {'id': '001229',
#   'code': 'DBFXLHPZHHA',
#   'name': '德邦福鑫灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'DEBANGFUXINLINGHUOPEIZHIHUNHEA'},
#  {'id': '001230',
#   'code': 'PHYYKJ',
#   'name': '鹏华医药科技',
#   'kind': '股票型',
#   'fullcode': 'PENGHUAYIYAOKEJI'},
#  {'id': '001231',
#   'code': 'YHTLLHPZHHA',
#   'name': '银华泰利灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'YINHUATAILILINGHUOPEIZHIHUNHEA'},
#  {'id': '001232',
#   'code': 'JHHBA',
#   'name': '嘉合货币A',
#   'kind': '货币型',
#   'fullcode': 'JIAHEHUOBIA'},
#  {'id': '001233',
#   'code': 'JHHBB',
#   'name': '嘉合货币B',
#   'kind': '货币型',
#   'fullcode': 'JIAHEHUOBIB'},
#  {'id': '001234',
#   'code': 'GJZYHB',
#   'name': '国金众赢货币',
#   'kind': '货币型',
#   'fullcode': 'GUOJINZHONGYINGHUOBI'},
#  {'id': '001235',
#   'code': 'ZYGYQYZA',
#   'name': '中银国有企业债A',
#   'kind': '债券型-长债',
#   'fullcode': 'ZHONGYINGUOYOUQIYEZHAIA'},
#  {'id': '001236',
#   'code': 'BSSLZTGPA',
#   'name': '博时丝路主题股票A',
#   'kind': '股票型',
#   'fullcode': 'BOSHISILUZHUTIGUPIAOA'},
#  {'id': '001237',
#   'code': 'BSSZ50ETFLJA',
#   'name': '博时上证50ETF联接A',
#   'kind': '指数型-股票',
#   'fullcode': 'BOSHISHANGZHENG50ETFLIANJIEA'},
#  {'id': '001239',
#   'code': 'CSGQGGHH',
#   'name': '长盛国企改革混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'CHANGSHENGGUOQIGAIGEHUNHE'},
#  {'id': '001240',
#   'code': 'MSJYXJZLHBD',
#   'name': '民生加银现金增利货币D',
#   'kind': '货币型',
#   'fullcode': 'MINSHENGJIAYINXIANJINZENGLIHUOBID'},
#  {'id': '001241',
#   'code': 'GSABZZ500ETFLJ',
#   'name': '国寿安保中证500ETF联接',
#   'kind': '指数型-股票',
#   'fullcode': 'GUOSHOUANBAOZHONGZHENG500ETFLIANJIE'},
#  {'id': '001242',
#   'code': 'BSZZTJDSJ100A',
#   'name': '博时中证淘金大数据100A',
#   'kind': '指数型-股票',
#   'fullcode': 'BOSHIZHONGZHENGTAOJINDASHUJU100A'},
#  {'id': '001243',
#   'code': 'BSZZTJDSJ100I',
#   'name': '博时中证淘金大数据100I',
#   'kind': '指数型-股票',
#   'fullcode': 'BOSHIZHONGZHENGTAOJINDASHUJU100I'},
#  {'id': '001244',
#   'code': 'HTBRLHZHHHA',
#   'name': '华泰柏瑞量化智慧混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUATAIBAIRUILIANGHUAZHIHUIHUNHEA'},
#  {'id': '001245',
#   'code': 'GYSTHJGP',
#   'name': '工银生态环境股票',
#   'kind': '股票型',
#   'fullcode': 'GONGYINSHENGTAIHUANJINGGUPIAO'},
#  {'id': '001246',
#   'code': 'XYCLDKZ',
#   'name': '兴银长乐定开债',
#   'kind': '债券型-长债',
#   'fullcode': 'XINGYINCHANGLEDINGKAIZHAI'},
#  {'id': '001247',
#   'code': 'HTBRXLHHA',
#   'name': '华泰柏瑞新利混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUATAIBAIRUIXINLIHUNHEA'},
#  {'id': '001249',
#   'code': 'YFDXLLHPZHH',
#   'name': '易方达新利灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'YIFANGDAXINLILINGHUOPEIZHIHUNHE'},
#  {'id': '001250',
#   'code': 'THXHLHH',
#   'name': '天弘新活力混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'TIANHONGXINHUOLIHUNHE'},
#  {'id': '001251',
#   'code': 'THXJGJHBD',
#   'name': '天弘现金管家货币D',
#   'kind': '货币型',
#   'fullcode': 'TIANHONGXIANJINGUANJIAHUOBID'},
#  {'id': '001252',
#   'code': 'ZHJQSYHH',
#   'name': '中海进取收益混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHONGHAIJINQUSHOUYIHUNHE'},
#  {'id': '001254',
#   'code': 'TDHLXQDHHA',
#   'name': '泰达宏利新起点混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'TAIDAHONGLIXINQIDIANHUNHEA'},
#  {'id': '001255',
#   'code': 'CCGGHLHH',
#   'name': '长城改革红利混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'CHANGCHENGGAIGEHONGLIHUNHE'},
#  {'id': '001256',
#   'code': 'HDYXCZHH',
#   'name': '泓德优选成长混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'HONGDEYOUXUANCHENGZHANGHUNHE'},
#  {'id': '001257',
#   'code': 'XYSYZQZQA',
#   'name': '兴业收益增强债券A',
#   'kind': '债券型-混合债',
#   'fullcode': 'XINGYESHOUYIZENGQIANGZHAIQUANA'},
#  {'id': '001258',
#   'code': 'XYSYZQZQC',
#   'name': '兴业收益增强债券C',
#   'kind': '债券型-混合债',
#   'fullcode': 'XINGYESHOUYIZENGQIANGZHAIQUANC'},
#  {'id': '001261',
#   'code': 'ZRXJYHH',
#   'name': '中融新机遇混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHONGRONGXINJIYUHUNHE'},
#  {'id': '001264',
#   'code': 'YHHLLHPZHHA',
#   'name': '银华恒利灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'YINHUAHENGLILINGHUOPEIZHIHUNHEA'},
#  {'id': '001265',
#   'code': 'GTXYLHPZHHA',
#   'name': '国泰兴益灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOTAIXINGYILINGHUOPEIZHIHUNHEA'},
#  {'id': '001266',
#   'code': 'GTRYZCHH',
#   'name': '国投瑞银招财混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'GUOTOURUIYINZHAOCAIHUNHE'},
#  {'id': '001267',
#   'code': 'TDHLLCHH',
#   'name': '泰达宏利蓝筹混合',
#   'kind': '混合型-偏股',
#   'fullcode': 'TAIDAHONGLILANCHOUHUNHE'},
#  {'id': '001268',
#   'code': 'FGGJAQZTHHA',
#   'name': '富国国家安全主题混合A',
#   'kind': '混合型-偏股',
#   'fullcode': 'FUGUOGUOJIAANQUANZHUTIHUNHEA'},
#  {'id': '001270',
#   'code': 'YDLHPZHHXFQSA',
#   'name': '英大灵活配置混合型发起式A',
#   'kind': '混合型-灵活',
#   'fullcode': 'YINGDALINGHUOPEIZHIHUNHEXINGFAQISHIA'},
#  {'id': '001271',
#   'code': 'YDLHPZHHXFQSB',
#   'name': '英大灵活配置混合型发起式B',
#   'kind': '混合型-灵活',
#   'fullcode': 'YINGDALINGHUOPEIZHIHUNHEXINGFAQISHIB'},
#  {'id': '001272',
#   'code': 'XYJLLHPZHH',
#   'name': '兴业聚利灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'XINGYEJULILINGHUOPEIZHIHUNHE'},
#  {'id': '001273',
#   'code': 'MSJYXDLHHA',
#   'name': '民生加银新动力混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'MINSHENGJIAYINXINDONGLIHUNHEA'},
#  {'id': '001274',
#   'code': 'MSJYXDLHHD',
#   'name': '民生加银新动力混合D',
#   'kind': '混合型-灵活',
#   'fullcode': 'MINSHENGJIAYINXINDONGLIHUNHED'},
#  {'id': '001275',
#   'code': 'ZYCXYSLHPZHH',
#   'name': '中邮创新优势灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHONGYOUCHUANGXINYOUSHILINGHUOPEIZHIHUNHE'},
#  {'id': '001276',
#   'code': 'JXXJJLHPZHH',
#   'name': '建信新经济灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'JIANXINXINJINGJILINGHUOPEIZHIHUNHE'},
#  {'id': '001277',
#   'code': 'BSGQGGGP',
#   'name': '博时国企改革股票',
#   'kind': '股票型',
#   'fullcode': 'BOSHIGUOQIGAIGEGUPIAO'},
#  {'id': '001278',
#   'code': 'QHKYQJNYHHA',
#   'name': '前海开源清洁能源混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'QIANHAIKAIYUANQINGJIENENGYUANHUNHEA'},
#  {'id': '001279',
#   'code': 'ZHJJZLHH',
#   'name': '中海积极增利混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'ZHONGHAIJIJIZENGLIHUNHE'},
#  {'id': '001280',
#   'code': 'YHJLLHPZHHA',
#   'name': '银华聚利灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'YINHUAJULILINGHUOPEIZHIHUNHEA'},
#  {'id': '001281',
#   'code': 'CAXLYXHHA',
#   'name': '长安鑫利优选混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'CHANGANXINLIYOUXUANHUNHEA'},
#  {'id': '001282',
#   'code': 'HAXJYLHPZ',
#   'name': '华安新机遇灵活配置',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUAANXINJIYULINGHUOPEIZHI'},
#  {'id': '001283',
#   'code': 'HTHTSJXDLHHA',
#   'name': '红塔红土盛金新动力混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'HONGTAHONGTUSHENGJINXINDONGLIHUNHEA'},
#  {'id': '001284',
#   'code': 'HTHTSJXDLHHC',
#   'name': '红塔红土盛金新动力混合C',
#   'kind': '混合型-灵活',
#   'fullcode': 'HONGTAHONGTUSHENGJINXINDONGLIHUNHEC'},
#  {'id': '001285',
#   'code': 'YFDXXHHI',
#   'name': '易方达新鑫混合I',
#   'kind': '混合型-灵活',
#   'fullcode': 'YIFANGDAXINXINHUNHEI'},
#  {'id': '001286',
#   'code': 'YFDXXHHE',
#   'name': '易方达新鑫混合E',
#   'kind': '混合型-灵活',
#   'fullcode': 'YIFANGDAXINXINHUNHEE'},
#  {'id': '001287',
#   'code': 'AXYSZZHHA',
#   'name': '安信优势增长混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'ANXINYOUSHIZENGZHANGHUNHEA'},
#  {'id': '001289',
#   'code': 'YHHLLHPZHHA',
#   'name': '银华汇利灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'YINHUAHUILILINGHUOPEIZHIHUNHEA'},
#  {'id': '001291',
#   'code': 'DMLHDCLGP',
#   'name': '大摩量化多策略股票',
#   'kind': '股票型',
#   'fullcode': 'DAMOLIANGHUADUOCELUEGUPIAO'},
#  {'id': '001294',
#   'code': 'XHZLXXCYLHPZHH',
#   'name': '新华战略新兴产业灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'XINHUAZHANLUEXINXINGCHANYELINGHUOPEIZHIHUNHE'},
#  {'id': '001296',
#   'code': 'CCZXCZLHPZHH',
#   'name': '长城转型成长灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'CHANGCHENGZHUANXINGCHENGZHANGLINGHUOPEIZHIHUNHE'},
#  {'id': '001297',
#   'code': 'PAZHZGHH',
#   'name': '平安智慧中国混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'PINGANZHIHUIZHONGGUOHUNHE'},
#  {'id': '001298',
#   'code': 'JYMZXXHH',
#   'name': '金鹰民族新兴混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'JINYINGMINZUXINXINGHUNHE'},
#  {'id': '001299',
#   'code': 'XYTLZQ',
#   'name': '兴业添利债券',
#   'kind': '债券型-长债',
#   'fullcode': 'XINGYETIANLIZHAIQUAN'},
#  {'id': '001300',
#   'code': 'DCRJLHPZHHA',
#   'name': '大成睿景灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'DACHENGRUIJINGLINGHUOPEIZHIHUNHEA'},
#  {'id': '001301',
#   'code': 'DCRJLHPZHHC',
#   'name': '大成睿景灵活配置混合C',
#   'kind': '混合型-灵活',
#   'fullcode': 'DACHENGRUIJINGLINGHUOPEIZHIHUNHEC'},
#  {'id': '001302',
#   'code': 'QHKYJYZBHHA',
#   'name': '前海开源金银珠宝混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'QIANHAIKAIYUANJINYINZHUBAOHUNHEA'},
#  {'id': '001303',
#   'code': 'YHWLLHPZHHA',
#   'name': '银华稳利灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'YINHUAWENLILINGHUOPEIZHIHUNHEA'},
#  {'id': '001304',
#   'code': 'JXXAHBLHPZHH',
#   'name': '建信鑫安回报灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'JIANXINXINANHUIBAOLINGHUOPEIZHIHUNHE'},
#  {'id': '001305',
#   'code': 'JTTFGGHHA',
#   'name': '九泰天富改革混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'JIUTAITIANFUGAIGEHUNHEA'},
#  {'id': '001306',
#   'code': 'ZOYYHHA',
#   'name': '中欧永裕混合A',
#   'kind': '混合型-偏股',
#   'fullcode': 'ZHONGOUYONGYUHUNHEA'},
#  {'id': '001307',
#   'code': 'ZOYYHHC',
#   'name': '中欧永裕混合C',
#   'kind': '混合型-偏股',
#   'fullcode': 'ZHONGOUYONGYUHUNHEC'},
#  {'id': '001308',
#   'code': 'BSWFHB',
#   'name': '博时外服货币',
#   'kind': '货币型',
#   'fullcode': 'BOSHIWAIFUHUOBI'},
#  {'id': '001309',
#   'code': 'DFHRYDQKFHH',
#   'name': '东方红睿逸定期开放混合',
#   'kind': '混合型-偏债',
#   'fullcode': 'DONGFANGHONGRUIYIDINGQIKAIFANGHUNHE'},
#  {'id': '001311',
#   'code': 'HAXHBLHPZHH',
#   'name': '华安新回报灵活配置混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUAANXINHUIBAOLINGHUOPEIZHIHUNHE'},
#  {'id': '001312',
#   'code': 'HAXYXLHPZHHA',
#   'name': '华安新优选灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUAANXINYOUXUANLINGHUOPEIZHIHUNHEA'},
#  {'id': '001313',
#   'code': 'STMGZHHLGP',
#   'name': '上投摩根智慧互联股票',
#   'kind': '股票型',
#   'fullcode': 'SHANGTOUMOGENZHIHUIHULIANGUPIAO'},
#  {'id': '001314',
#   'code': 'YFDXYHHI',
#   'name': '易方达新益混合I',
#   'kind': '混合型-灵活',
#   'fullcode': 'YIFANGDAXINYIHUNHEI'},
#  {'id': '001315',
#   'code': 'YFDXYHHE',
#   'name': '易方达新益混合E',
#   'kind': '混合型-灵活',
#   'fullcode': 'YIFANGDAXINYIHUNHEE'},
#  {'id': '001316',
#   'code': 'AXWJZZHHA',
#   'name': '安信稳健增值混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'ANXINWENJIANZENGZHIHUNHEA'},
#  {'id': '001318',
#   'code': 'DFXCLLHPZHHA',
#   'name': '东方新策略灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'DONGFANGXINCELUELINGHUOPEIZHIHUNHEA'},
#  {'id': '001319',
#   'code': 'NYXXCMGP',
#   'name': '农银信息传媒股票',
#   'kind': '股票型',
#   'fullcode': 'NONGYINXINXICHUANMEIGUPIAO'},
#  {'id': '001320',
#   'code': 'GYFYHBLHPZHHA',
#   'name': '工银丰盈回报灵活配置混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'GONGYINFENGYINGHUIBAOLINGHUOPEIZHIHUNHEA'},
#  {'id': '001322',
#   'code': 'DWXQSJZXHH',
#   'name': '东吴新趋势价值线混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'DONGWUXINQUSHIJIAZHIXIANHUNHE'},
#  {'id': '001323',
#   'code': 'DWYDHLHHA',
#   'name': '东吴移动互联混合A',
#   'kind': '混合型-灵活',
#   'fullcode': 'DONGWUYIDONGHULIANHUNHEA'},
#  {'id': '001324',
#   'code': 'HBXJZHH',
#   'name': '华宝新价值混合',
#   'kind': '混合型-灵活',
#   'fullcode': 'HUABAOXINJIAZHIHUNHE'},
#  ...]

# %%
def expand(match):
    if match:
        return match.groups()

# %%
def to_dict(keys):
    def wrap(items):
        if items is None:
            return None
        if len(keys) != len(items):
            raise f"{keys} don't match {items}"
        return dict(zip(keys, items))
    return wrap

# %%
id = lambda one: one

# %%
keys = ["date", "price", "acc_price", "daily_change_percent", "buy_status", "sell_status", "dividends"]
tr_re = re.compile(r'<tr>(.*?)</tr>')
item_re = re.compile(r'''<td>(\d{4}-\d{2}-\d{2})</td><td.*?>(.*?)</td><td.*?>(.*?)</td><td.*?>(.*?)</td><td.*?>(.*?)</td><td.*?>(.*?)</td><td.*?>(.*?)</td>''', re.X)
to_dict_ = to_dict(keys)

# %%
dividends_re = re.compile(r"每份派现金([\d\.]+)元")
dividends_re_2 = re.compile(r"每份基金份额折算([\.\d]+)份")
def calc_dividends(val, price):
    if not val or not price:
        return 0.0
    match = dividends_re.match(val)
    if match:
        return float(match.groups()[0])
    match = dividends_re_2.match(val)
    if match:
        return (float(match.groups()[0]) - 1.0) * price
def numerize(item):
    if item is None:
        return None
    fomatter = {
        "date": lambda val: datetime.strptime(val, '%Y-%m-%d'),
        "price": lambda val: float(val) if val else 0.0,
        "acc_price": lambda val: float(val) if val else 0.0,
        "daily_change_percent": lambda val: float(val[:-1] if val[:-1] else 0) / 100,
        "dividends": id,
        "buy_status": id,
        "sell_status": id,
    }
    for key in keys:
        item[key] = fomatter[key](item[key])
    item["dividends"] = calc_dividends(item["dividends"], item["price"])
    item["dividends_percent"] = item["dividends"] / item["price"] if item["dividends"] and item["price"] else 0.0
    return item

# %%
fund_id = "002001"
page_re = re.compile(r"pages:(\d+),", re.X)
def get_fund_data(fund_id, page):
    res = requests.get(f"https://fundf10.eastmoney.com/F10DataApi.aspx?type=lsjz&code={fund_id}&page={page}&per=50&sdate=2020-09-10&edate=2021-09-10")
    content = res.content.decode("utf-8")
    lines = tr_re.findall(content)
    table = list(filter(id, [numerize(to_dict_(expand(item_re.match(line)))) for line in lines]))
    total_page = int(page_re.findall(content)[0])
    return table, total_page

# %%
def get_fund_year_data(fund_id):
    current = 1
    total_page = 1
    table = []
    while current <= total_page:
        page, total_page = get_fund_data(fund_id, current)
        table += page
        current += 1
    return table

# %%
def deduplicate(funds):
    fund_ids = set()
    funds_new = []
    for fund in funds:
        if fund["id"] not in fund_ids:
            fund_ids.add(fund["id"])
        funds_new.append(fund)
    return funds_new

# %%
fund_1 = get_fund_year_data(fund_id)

# %%
def get_metrics(table):
    return {
        "dividends_count": len(list(filter(lambda one: one["dividends"] > 0, table))),
        "anual_dividends_percent": sum(map(lambda one: one["dividends_percent"], table)),
        "dividends_std": np.std(list(map(lambda one: one["dividends"], table))),
        "dividends_percent_std": np.std(list(map(lambda one: one["dividends_percent"], table))),
        "price_std": np.std(list(map(lambda one: one["price"], table))),
    }

# %%
get_metrics(fund_1)
# Out:
# {'dividends_count': 14,
#  'anual_dividends_percent': 0.17762188421776784,
#  'dividends_std': 0.005685642497752113,
#  'dividends_percent_std': 0.0032725857559546294,
#  'price_std': 0.1412083561623124}

# %%
dividend_funds = []

# %%
for fund in funds[2000:4000]:
    table = get_fund_year_data(fund["id"])
    metric = get_metrics(table)
    if metric["anual_dividends_percent"] > 0.04:
        fund = deepcopy(fund)
        fund["metric"] = metric
        fund["table"] = table
        dividend_funds.append(fund)

# %%
len(dividend_funds)
# Out:
# 236

# %%
dividend_funds = deduplicate(dividend_funds)

# %%
sorted([[fund["id"], fund["name"], fund["metric"]] for fund in dividend_funds], key=lambda one: one[2]["anual_dividends_percent"], reverse=True)
# Out:
# [['000939',
#   '中银研究精选灵活配置混合A',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.5059669912509068,
#    'dividends_std': 0.020132134937528537,
#    'dividends_percent_std': 0.017258287550931655,
#    'price_std': 0.10966266202267391}],
#  ['000743',
#   '红塔红土盛世普益混合发起式',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.4933833860293311,
#    'dividends_std': 0.023130355475863687,
#    'dividends_percent_std': 0.021176786950070553,
#    'price_std': 0.19221420514292262}],
#  ['002303',
#   '金鹰智慧生活混合',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.47904615357631697,
#    'dividends_std': 0.0288992977898199,
#    'dividends_percent_std': 0.022635065641531234,
#    'price_std': 0.1915066215716555}],
#  ['001007',
#   '国联安鑫安灵活配置混合',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.44077288285481997,
#    'dividends_std': 0.017295682257132607,
#    'dividends_percent_std': 0.014184793634911392,
#    'price_std': 0.15585291349398883}],
#  ['002407',
#   '前海开源恒远灵活配置混合',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.411856794690084,
#    'dividends_std': 0.019268758770518535,
#    'dividends_percent_std': 0.013751676604279407,
#    'price_std': 0.16922063711120816}],
#  ['000824',
#   '圆信永丰双利A',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.4044969605364803,
#    'dividends_std': 0.01733474656291999,
#    'dividends_percent_std': 0.013409297966068084,
#    'price_std': 0.07567492502397623}],
#  ['000825',
#   '圆信永丰双利C',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.3914320829875266,
#    'dividends_std': 0.016759110788433618,
#    'dividends_percent_std': 0.012980879177358852,
#    'price_std': 0.07458438456311119}],
#  ['001943',
#   '前海开源沪港深汇鑫混合C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.3894181373043787,
#    'dividends_std': 0.025655910416028934,
#    'dividends_percent_std': 0.017907151653859376,
#    'price_std': 0.18340881068458706}],
#  ['001705',
#   '泓德战略转型股票',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.38840419224166717,
#    'dividends_std': 0.03181579635902869,
#    'dividends_percent_std': 0.01767324539575781,
#    'price_std': 0.1733903874977928}],
#  ['001942',
#   '前海开源沪港深汇鑫混合A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.3827712458281982,
#    'dividends_std': 0.025655910416028934,
#    'dividends_percent_std': 0.017606641343753806,
#    'price_std': 0.18260469107564611}],
#  ['001938',
#   '中欧时代先锋股票A',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.34881674017127534,
#    'dividends_std': 0.02461099803928715,
#    'dividends_percent_std': 0.013090582240541097,
#    'price_std': 0.09874827681244741}],
#  ['001457',
#   '华商新常态混合',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.33430374979114336,
#    'dividends_std': 0.02012377360379119,
#    'dividends_percent_std': 0.015091087644437106,
#    'price_std': 0.0796843736265141}],
#  ['000523',
#   '国投瑞银医疗保健混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.31855090568394756,
#    'dividends_std': 0.03251614150785626,
#    'dividends_percent_std': 0.020309894758186314,
#    'price_std': 0.2635056528575432}],
#  ['000663',
#   '国投瑞银美丽中国混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.3084577114427861,
#    'dividends_std': 0.03952942693111939,
#    'dividends_percent_std': 0.019666381557770837,
#    'price_std': 0.1818468260788058}],
#  ['000279',
#   '华商红利优选混合',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.29523960393884136,
#    'dividends_std': 0.009605525620650835,
#    'dividends_percent_std': 0.009415199850028174,
#    'price_std': 0.05330042411021727}],
#  ['000520',
#   '上银新兴价值成长混合',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.2907826269378567,
#    'dividends_std': 0.019615456442439238,
#    'dividends_percent_std': 0.013388199525470493,
#    'price_std': 0.12615567450870185}],
#  ['000390',
#   '华商优势行业混合',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.27044937636347965,
#    'dividends_std': 0.014936888472318641,
#    'dividends_percent_std': 0.012172247590247457,
#    'price_std': 0.08566506205649337}],
#  ['001901',
#   '前海开源沪港深隆鑫混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.26501766784452296,
#    'dividends_std': 0.019127142063444867,
#    'dividends_percent_std': 0.016896768607283452,
#    'price_std': 0.09964729135247923}],
#  ['002545',
#   '东方岳灵活配置混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.26214757048590287,
#    'dividends_std': 0.022334937134978347,
#    'dividends_percent_std': 0.016747853280577638,
#    'price_std': 0.10222158581314546}],
#  ['001902',
#   '前海开源沪港深隆鑫混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.2579535683576956,
#    'dividends_std': 0.019127142063444867,
#    'dividends_percent_std': 0.016446381825833935,
#    'price_std': 0.1012626667638833}],
#  ['000017',
#   '财通可持续混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.2361308677098151,
#    'dividends_std': 0.03175105582531848,
#    'dividends_percent_std': 0.015055028840833796,
#    'price_std': 0.16754363025289074}],
#  ['001178',
#   '前海开源再融资股票',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.2356020942408377,
#    'dividends_std': 0.02295257047613385,
#    'dividends_percent_std': 0.015021315756632089,
#    'price_std': 0.1908655087113964}],
#  ['000634',
#   '富国天盛灵活配置基金',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.23129086993695042,
#    'dividends_std': 0.013188101865715608,
#    'dividends_percent_std': 0.007431857184353091,
#    'price_std': 0.10770035359319062}],
#  ['001875',
#   '前海开源沪港深优势精选混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.22530329289428078,
#    'dividends_std': 0.0331537129099711,
#    'dividends_percent_std': 0.014364693635169457,
#    'price_std': 0.15579434558882765}],
#  ['001604',
#   '浙商汇金转型升级灵活配置混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.21776923076923077,
#    'dividends_std': 0.018049646393870807,
#    'dividends_percent_std': 0.013884343379900618,
#    'price_std': 0.10497182946513703}],
#  ['001156',
#   '申万菱信新能源汽车混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.20921985815602837,
#    'dividends_std': 0.037616712724774896,
#    'dividends_percent_std': 0.013339259831480458,
#    'price_std': 0.5006497429319982}],
#  ['000845',
#   '国投瑞银信息消费混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.19825535289452817,
#    'dividends_std': 0.015939285052870726,
#    'dividends_percent_std': 0.012640194332173458,
#    'price_std': 0.09501996808930985}],
#  ['002163',
#   '东方惠新灵活配置混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.18961297924408593,
#    'dividends_std': 0.013337993732242214,
#    'dividends_percent_std': 0.012089181303582188,
#    'price_std': 0.09617886004142041}],
#  ['002514',
#   '招商丰益混合A',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.18816048900663473,
#    'dividends_std': 0.008098271883363532,
#    'dividends_percent_std': 0.005975889841971847,
#    'price_std': 0.038631827023090995}],
#  ['002155',
#   '国金鑫瑞灵活配置混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.18511146496815287,
#    'dividends_std': 0.011858828079335818,
#    'dividends_percent_std': 0.011802177626727521,
#    'price_std': 0.054934831838320396}],
#  ['002021',
#   '华夏回报二号混合',
#   {'dividends_count': 15,
#    'anual_dividends_percent': 0.18315824468424366,
#    'dividends_std': 0.004563586568224709,
#    'dividends_percent_std': 0.003138044486133694,
#    'price_std': 0.12123764472016436}],
#  ['002452',
#   '民生加银和鑫定开债',
#   {'dividends_count': 5,
#    'anual_dividends_percent': 0.18310112366795142,
#    'dividends_std': 0.006154017470623399,
#    'dividends_percent_std': 0.005798536862548725,
#    'price_std': 0.07546859372436895}],
#  ['002451',
#   '平安睿享文娱混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.18285172903837044,
#    'dividends_std': 0.02461025612163241,
#    'dividends_percent_std': 0.011658103326211467,
#    'price_std': 0.11800159776976854}],
#  ['002450',
#   '平安睿享文娱混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.18206645425580337,
#    'dividends_std': 0.02550285608459316,
#    'dividends_percent_std': 0.011608036451794786,
#    'price_std': 0.12342341394040561}],
#  ['001198',
#   '东方惠新灵活配置混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.17822858177866327,
#    'dividends_std': 0.01254740519361984,
#    'dividends_percent_std': 0.011363344678155978,
#    'price_std': 0.09018076827367714}],
#  ['002515',
#   '招商丰益混合C',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.17780709836018826,
#    'dividends_std': 0.00706438056164163,
#    'dividends_percent_std': 0.00565420204107998,
#    'price_std': 0.03541328410891303}],
#  ['002001',
#   '华夏回报混合A',
#   {'dividends_count': 14,
#    'anual_dividends_percent': 0.17762188421776784,
#    'dividends_std': 0.005685642497752113,
#    'dividends_percent_std': 0.0032725857559546294,
#    'price_std': 0.1412083561623124}],
#  ['002376',
#   '国寿安保核心产业混合',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.17686850723008843,
#    'dividends_std': 0.006676183683170242,
#    'dividends_percent_std': 0.005633498497379327,
#    'price_std': 0.0646586423070388}],
#  ['002316',
#   '创金合信中证500指数增强C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.17534942820838625,
#    'dividends_std': 0.014077576558695421,
#    'dividends_percent_std': 0.011179778080285438,
#    'price_std': 0.053286639875030385}],
#  ['002311',
#   '创金合信中证500指数增强A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.1753437723551387,
#    'dividends_std': 0.014064825130653125,
#    'dividends_percent_std': 0.011179417479256918,
#    'price_std': 0.05322364935482689}],
#  ['001037',
#   '国投瑞银锐意改革混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.17501988862370726,
#    'dividends_std': 0.014026570846526242,
#    'dividends_percent_std': 0.011158767578779826,
#    'price_std': 0.08849621804393658}],
#  ['000398',
#   '华富灵活配置混合',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.17366368022638615,
#    'dividends_std': 0.00604495170090071,
#    'dividends_percent_std': 0.005516172791900037,
#    'price_std': 0.04860955012322174}],
#  ['001601',
#   '鑫元鑫新收益灵活配置混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.1730225988700565,
#    'dividends_std': 0.01249639948145065,
#    'dividends_percent_std': 0.011031426095913354,
#    'price_std': 0.06345830277108942}],
#  ['000884',
#   '民生加银优选股票',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.1683760683760684,
#    'dividends_std': 0.025120313243324265,
#    'dividends_percent_std': 0.010735176599711222,
#    'price_std': 0.10457238875437397}],
#  ['002562',
#   '泓德泓益量化混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.16742005692281933,
#    'dividends_std': 0.01912714206344487,
#    'dividends_percent_std': 0.010674224043442636,
#    'price_std': 0.09445149107662223}],
#  ['002410',
#   '华夏新活力混合C',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.16700427408677176,
#    'dividends_std': 0.006082400636347562,
#    'dividends_percent_std': 0.005291083241582914,
#    'price_std': 0.04156199606452958}],
#  ['002409',
#   '华夏新活力混合A',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.1668783637758587,
#    'dividends_std': 0.00622174253190196,
#    'dividends_percent_std': 0.005287094416576865,
#    'price_std': 0.04190858419708802}],
#  ['000566',
#   '华泰柏瑞创新升级混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.16635086573015354,
#    'dividends_std': 0.032465135795687085,
#    'dividends_percent_std': 0.010606055470658963,
#    'price_std': 0.18613701142457978}],
#  ['002326',
#   '银华聚利灵活配置混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.1643743536711479,
#    'dividends_std': 0.020268394873230417,
#    'dividends_percent_std': 0.010480038714183251,
#    'price_std': 0.09012821114380155}],
#  ['001280',
#   '银华聚利灵活配置混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.1641950228542407,
#    'dividends_std': 0.02061268343037241,
#    'dividends_percent_std': 0.010468605094145465,
#    'price_std': 0.09145622795989926}],
#  ['001520',
#   '国投瑞银研究精选股票',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.16064981949458484,
#    'dividends_std': 0.017023156436465934,
#    'dividends_percent_std': 0.010242573066465662,
#    'price_std': 0.11777368127047741}],
#  ['002059',
#   '国泰浓益灵活配置混合C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.16002574907762274,
#    'dividends_std': 0.0175790075858998,
#    'dividends_percent_std': 0.007330567047574596,
#    'price_std': 0.06843552932726081}],
#  ['000326',
#   '南方中小盘成长股票',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.15979539677194646,
#    'dividends_std': 0.01211456212897697,
#    'dividends_percent_std': 0.007211356950211041,
#    'price_std': 0.0663171986603081}],
#  ['000241',
#   '宝盈核心优势混合C',
#   {'dividends_count': 12,
#    'anual_dividends_percent': 0.1569051502505668,
#    'dividends_std': 0.0037453288969647234,
#    'dividends_percent_std': 0.0029154833879929684,
#    'price_std': 0.11489876989310534}],
#  ['002063',
#   '国泰沪深300指数增强C',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.15198993381226183,
#    'dividends_std': 0.008612234684199378,
#    'dividends_percent_std': 0.005571807214966472,
#    'price_std': 0.06127927439507862}],
#  ['001645',
#   '国泰大健康股票A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.15170761323179213,
#    'dividends_std': 0.01959672558050752,
#    'dividends_percent_std': 0.007109920079195079,
#    'price_std': 0.15132664406122323}],
#  ['000512',
#   '国泰沪深300指数增强A',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.1508499370291333,
#    'dividends_std': 0.008704660784139173,
#    'dividends_percent_std': 0.0055302196988808745,
#    'price_std': 0.06235481053082321}],
#  ['001602',
#   '鑫元鑫新收益灵活配置混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.15072258178916573,
#    'dividends_std': 0.01083871383595209,
#    'dividends_percent_std': 0.009609640780168538,
#    'price_std': 0.06121428150269929}],
#  ['002574',
#   '招商瑞庆混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.14783116125267456,
#    'dividends_std': 0.0096910853121454,
#    'dividends_percent_std': 0.009425292075613113,
#    'price_std': 0.037140120948779394}],
#  ['002095',
#   '博时新收益A',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.14283581808147408,
#    'dividends_std': 0.007144779613007711,
#    'dividends_percent_std': 0.005237248662650116,
#    'price_std': 0.11823941142865077}],
#  ['002096',
#   '博时新收益C',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.14211004488894088,
#    'dividends_std': 0.0070932285229506386,
#    'dividends_percent_std': 0.005210460229910633,
#    'price_std': 0.11783814575122013}],
#  ['000953',
#   '国泰睿吉灵活配置混合A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.1405486110567553,
#    'dividends_std': 0.006439389614622875,
#    'dividends_percent_std': 0.006359819067226999,
#    'price_std': 0.024661296097282383}],
#  ['001009',
#   '上投摩根安全战略股票',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.1335354957491742,
#    'dividends_std': 0.015722510776151676,
#    'dividends_percent_std': 0.008513841325689983,
#    'price_std': 0.16737344060635237}],
#  ['000879',
#   '中海医药健康产业精选混合C',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.13316442801151776,
#    'dividends_std': 0.010082058984623598,
#    'dividends_percent_std': 0.004407556467772133,
#    'price_std': 0.12531467071819444}],
#  ['001358',
#   '宝盈祥泰混合A',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.13168021433882712,
#    'dividends_std': 0.005653051263529129,
#    'dividends_percent_std': 0.004835933000345738,
#    'price_std': 0.03849378852622903}],
#  ['000954',
#   '国泰睿吉灵活配置混合C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.1316654331291435,
#    'dividends_std': 0.00604960345456772,
#    'dividends_percent_std': 0.005994351141077515,
#    'price_std': 0.022873672594473857}],
#  ['000878',
#   '中海医药健康产业精选混合A',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.12573763244688582,
#    'dividends_std': 0.010082058984623598,
#    'dividends_percent_std': 0.0041557634925718226,
#    'price_std': 0.13374085891295093}],
#  ['000526',
#   '国泰浓益灵活配置混合A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.12544382170838345,
#    'dividends_std': 0.008054789474967516,
#    'dividends_percent_std': 0.006325589883357052,
#    'price_std': 0.034426746863814424}],
#  ['001342',
#   '易方达新享混合A',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.12186263506727998,
#    'dividends_std': 0.006575985237278109,
#    'dividends_percent_std': 0.004494517943402188,
#    'price_std': 0.02656491471617311}],
#  ['002109',
#   '博时裕丰纯债3个月定开债',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.11688613620869198,
#    'dividends_std': 0.007277266991719554,
#    'dividends_percent_std': 0.007120960414568738,
#    'price_std': 0.03193221177256141}],
#  ['001985',
#   '富国低碳新经济混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.11466011466011466,
#    'dividends_std': 0.01785199925921521,
#    'dividends_percent_std': 0.007310401007049635,
#    'price_std': 0.30110118166379485}],
#  ['001371',
#   '富国沪港深价值混合A',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.11261760043931085,
#    'dividends_std': 0.0071006332173004505,
#    'dividends_percent_std': 0.004223348980359858,
#    'price_std': 0.09200990294926427}],
#  ['001910',
#   '泰康新机遇混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.11192526103681993,
#    'dividends_std': 0.011686683800764812,
#    'dividends_percent_std': 0.007136034561131352,
#    'price_std': 0.15086404503712805}],
#  ['001244',
#   '华泰柏瑞量化智慧混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.1110417479516192,
#    'dividends_std': 0.009072641052094012,
#    'dividends_percent_std': 0.00707970429347953,
#    'price_std': 0.09297692652107899}],
#  ['000417',
#   '国联安新精选混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.10603809266513577,
#    'dividends_std': 0.010009871013202812,
#    'dividends_percent_std': 0.0067606855418092734,
#    'price_std': 0.06709512972255485}],
#  ['002455',
#   '民生加银鑫喜混合',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.10254435001118509,
#    'dividends_std': 0.00575905552439905,
#    'dividends_percent_std': 0.004613536038280651,
#    'price_std': 0.02540604759981171}],
#  ['002046',
#   '信诚新锐混合B',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.1010448594510215,
#    'dividends_std': 0.005038950328011109,
#    'dividends_percent_std': 0.004546239994947636,
#    'price_std': 0.0257642048663419}],
#  ['002592',
#   '中欧纯债债券(LOF)E',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.09985164278477349,
#    'dividends_std': 0.005174119429434746,
#    'dividends_percent_std': 0.004492721857439679,
#    'price_std': 0.03736109779554305}],
#  ['000006',
#   '西部利得量化成长混合A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.0987614448938384,
#    'dividends_std': 0.009469049958788498,
#    'dividends_percent_std': 0.004443868925880127,
#    'price_std': 0.22493917250584322}],
#  ['000011',
#   '华夏大盘精选混合A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.0969591864918724,
#    'dividends_std': 0.08394430572691244,
#    'dividends_percent_std': 0.004364431717527765,
#    'price_std': 0.6866864883344809}],
#  ['002414',
#   '中银瑞利混合C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.09515863717589142,
#    'dividends_std': 0.004824372387120699,
#    'dividends_percent_std': 0.004295806291802955,
#    'price_std': 0.023395533841920287}],
#  ['002413',
#   '中银瑞利混合A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.09495166251417764,
#    'dividends_std': 0.004824372387120699,
#    'dividends_percent_std': 0.004286605269567189,
#    'price_std': 0.023398482420700632}],
#  ['000674',
#   '中海中短债债券',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.09198997166748663,
#    'dividends_std': 0.0030391201953606953,
#    'dividends_percent_std': 0.0033676752514616983,
#    'price_std': 0.01902104719956545}],
#  ['001325',
#   '鹏华弘和混合A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.0917639120270781,
#    'dividends_std': 0.005175696899999688,
#    'dividends_percent_std': 0.00412928216518636,
#    'price_std': 0.025802211793650522}],
#  ['002619',
#   '中银裕利混合C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.09130563070804204,
#    'dividends_std': 0.005167778941866935,
#    'dividends_percent_std': 0.004143533717644311,
#    'price_std': 0.01948730617711993}],
#  ['002618',
#   '中银裕利混合A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.09112827548220606,
#    'dividends_std': 0.005167778941866935,
#    'dividends_percent_std': 0.004135687519687012,
#    'price_std': 0.019546859938220217}],
#  ['002023',
#   '红塔红土稳健回报A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.08977702661697914,
#    'dividends_std': 0.004319100281152379,
#    'dividends_percent_std': 0.004039951034242561,
#    'price_std': 0.018160053584422266}],
#  ['002270',
#   '东吴安盈量化混合',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.08843006100267232,
#    'dividends_std': 0.004247938471518772,
#    'dividends_percent_std': 0.0032625834270496785,
#    'price_std': 0.05380157921967172}],
#  ['001881',
#   '中欧新趋势混合E',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.08738583065909651,
#    'dividends_std': 0.011285013817432472,
#    'dividends_percent_std': 0.005571470657828919,
#    'price_std': 0.09094784270006125}],
#  ['001326',
#   '鹏华弘和混合C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.08728141655640437,
#    'dividends_std': 0.00486234672356277,
#    'dividends_percent_std': 0.003928561898964013,
#    'price_std': 0.025096355533381586}],
#  ['000129',
#   '大成景安短融债券B',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.08475738043356468,
#    'dividends_std': 0.004725959572145219,
#    'dividends_percent_std': 0.0038134802801325107,
#    'price_std': 0.037607629256030735}],
#  ['001415',
#   '信诚新锐混合A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.08466796140773311,
#    'dividends_std': 0.003925381816757483,
#    'dividends_percent_std': 0.003877428742191791,
#    'price_std': 0.027035406775040016}],
#  ['002086',
#   '大成景安短融债券E',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.08341404438156774,
#    'dividends_std': 0.0045890440487244034,
#    'dividends_percent_std': 0.003753521916620253,
#    'price_std': 0.03671634057618111}],
#  ['002024',
#   '红塔红土稳健回报C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.08195302553948844,
#    'dividends_std': 0.003916530181558296,
#    'dividends_percent_std': 0.0036925191870614596,
#    'price_std': 0.01758759698897864}],
#  ['000128',
#   '大成景安短融债券A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.08173081680091711,
#    'dividends_std': 0.004456133547978307,
#    'dividends_percent_std': 0.0036816659637964747,
#    'price_std': 0.036074312527381566}],
#  ['000024',
#   '大摩双利增强债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.0814604164755527,
#    'dividends_std': 0.005661634050779678,
#    'dividends_percent_std': 0.005193683194917602,
#    'price_std': 0.021635962873482743}],
#  ['000338',
#   '鹏华双债保利债券',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.08145943695883848,
#    'dividends_std': 0.004456133547978307,
#    'dividends_percent_std': 0.0036657719226746164,
#    'price_std': 0.02162244389055232}],
#  ['001126',
#   '上投摩根卓越制造股票',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.0800420297917053,
#    'dividends_std': 0.008256549657387032,
#    'dividends_percent_std': 0.005103250916241444,
#    'price_std': 0.13030854747875326}],
#  ['002524',
#   '兴业福益债券',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.07719588455602827,
#    'dividends_std': 0.0038308682897476936,
#    'dividends_percent_std': 0.003476355232175339,
#    'price_std': 0.029005002840101046}],
#  ['001343',
#   '易方达新享混合C',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.0745153265741594,
#    'dividends_std': 0.0033371085105465205,
#    'dividends_percent_std': 0.0028307919029763188,
#    'price_std': 0.013299798171535614}],
#  ['000187',
#   '华泰柏瑞丰盛纯债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.07450084434290255,
#    'dividends_std': 0.004781785515861217,
#    'dividends_percent_std': 0.0047499607786443,
#    'price_std': 0.026347760286912613}],
#  ['000187',
#   '华泰柏瑞丰盛纯债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.07450084434290255,
#    'dividends_std': 0.004781785515861217,
#    'dividends_percent_std': 0.0047499607786443,
#    'price_std': 0.026347760286912613}],
#  ['000025',
#   '大摩双利增强债券C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.0739988927846466,
#    'dividends_std': 0.005113322644960929,
#    'dividends_percent_std': 0.004717957782765201,
#    'price_std': 0.01965420127661616}],
#  ['002552',
#   '华夏恒利定开债',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.07267004929110618,
#    'dividends_std': 0.0034240592271460126,
#    'dividends_percent_std': 0.003272136425447451,
#    'price_std': 0.020586927891261486}],
#  ['000817',
#   '中银安心回报',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.07051973999262057,
#    'dividends_std': 0.006447044069313782,
#    'dividends_percent_std': 0.006415802369262856,
#    'price_std': 0.012730809635198164}],
#  ['000118',
#   '广发聚鑫债券A',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.07034587924349223,
#    'dividends_std': 0.0035249193219947976,
#    'dividends_percent_std': 0.002341070901800353,
#    'price_std': 0.014291371567877199}],
#  ['001770',
#   '前海开源嘉鑫混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.06890611541774333,
#    'dividends_std': 0.0051005712169186306,
#    'dividends_percent_std': 0.004393256862117685,
#    'price_std': 0.03522525739935023}],
#  ['001765',
#   '前海开源嘉鑫混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.06843455945252352,
#    'dividends_std': 0.0051005712169186306,
#    'dividends_percent_std': 0.004363191802325604,
#    'price_std': 0.0357811609447011}],
#  ['000045',
#   '工银产业债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.06788866259334692,
#    'dividends_std': 0.006375714021148289,
#    'dividends_percent_std': 0.004328386979734074,
#    'price_std': 0.02247653373920482}],
#  ['000045',
#   '工银产业债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.06788866259334692,
#    'dividends_std': 0.006375714021148289,
#    'dividends_percent_std': 0.004328386979734074,
#    'price_std': 0.02247653373920482}],
#  ['000045',
#   '工银产业债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.06788866259334692,
#    'dividends_std': 0.006375714021148289,
#    'dividends_percent_std': 0.004328386979734074,
#    'price_std': 0.02247653373920482}],
#  ['000045',
#   '工银产业债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.06788866259334692,
#    'dividends_std': 0.006375714021148289,
#    'dividends_percent_std': 0.004328386979734074,
#    'price_std': 0.02247653373920482}],
#  ['001947',
#   '上投摩根安鑫回报A',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.06781311548115716,
#    'dividends_std': 0.0024142229161751047,
#    'dividends_percent_std': 0.0023253112116498123,
#    'price_std': 0.0159592314616276}],
#  ['001960',
#   '兴银瑞益',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.06674013744056102,
#    'dividends_std': 0.002531981196548493,
#    'dividends_percent_std': 0.002522519178418646,
#    'price_std': 0.010016833811148445}],
#  ['000119',
#   '广发聚鑫债券C',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.06653705178643535,
#    'dividends_std': 0.0033388154281332114,
#    'dividends_percent_std': 0.0022229352773126135,
#    'price_std': 0.014029135589827008}],
#  ['000137',
#   '民生加银岁岁增利债券A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.06583180691356029,
#    'dividends_std': 0.003381848797792222,
#    'dividends_percent_std': 0.002970123887892559,
#    'price_std': 0.014074346437939618}],
#  ['000137',
#   '民生加银岁岁增利债券A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.06583180691356029,
#    'dividends_std': 0.003381848797792222,
#    'dividends_percent_std': 0.002970123887892559,
#    'price_std': 0.014074346437939618}],
#  ['000137',
#   '民生加银岁岁增利债券A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.06583180691356029,
#    'dividends_std': 0.003381848797792222,
#    'dividends_percent_std': 0.002970123887892559,
#    'price_std': 0.014074346437939618}],
#  ['000137',
#   '民生加银岁岁增利债券A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.06583180691356029,
#    'dividends_std': 0.003381848797792222,
#    'dividends_percent_std': 0.002970123887892559,
#    'price_std': 0.014074346437939618}],
#  ['000256',
#   '上投摩根红利回报混合A',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.06544130862078334,
#    'dividends_std': 0.0022644658177928935,
#    'dividends_percent_std': 0.002205248073014754,
#    'price_std': 0.017279940837379687}],
#  ['000165',
#   '国投瑞银策略精选混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.06516072980017376,
#    'dividends_std': 0.009563571031722434,
#    'dividends_percent_std': 0.004154461786152232,
#    'price_std': 0.21900930334600696}],
#  ['000165',
#   '国投瑞银策略精选混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.06516072980017376,
#    'dividends_std': 0.009563571031722434,
#    'dividends_percent_std': 0.004154461786152232,
#    'price_std': 0.21900930334600696}],
#  ['000165',
#   '国投瑞银策略精选混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.06516072980017376,
#    'dividends_std': 0.009563571031722434,
#    'dividends_percent_std': 0.004154461786152232,
#    'price_std': 0.21900930334600696}],
#  ['001903',
#   '光大欣鑫混合A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.06307673160467803,
#    'dividends_std': 0.004811280649790178,
#    'dividends_percent_std': 0.003008101801620126,
#    'price_std': 0.030932500575232096}],
#  ['001904',
#   '光大欣鑫混合C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.06188925285959793,
#    'dividends_std': 0.003700616245944735,
#    'dividends_percent_std': 0.0029393970730277465,
#    'price_std': 0.0240528108396461}],
#  ['000046',
#   '工银产业债债券B',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.0615491009681881,
#    'dividends_std': 0.005674385478821974,
#    'dividends_percent_std': 0.0039241946603194855,
#    'price_std': 0.02007999412595261}],
#  ['000046',
#   '工银产业债债券B',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.0615491009681881,
#    'dividends_std': 0.005674385478821974,
#    'dividends_percent_std': 0.0039241946603194855,
#    'price_std': 0.02007999412595261}],
#  ['000046',
#   '工银产业债债券B',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.0615491009681881,
#    'dividends_std': 0.005674385478821974,
#    'dividends_percent_std': 0.0039241946603194855,
#    'price_std': 0.02007999412595261}],
#  ['000046',
#   '工银产业债债券B',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.0615491009681881,
#    'dividends_std': 0.005674385478821974,
#    'dividends_percent_std': 0.0039241946603194855,
#    'price_std': 0.02007999412595261}],
#  ['000255',
#   '长城定开债C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.061327329761489205,
#    'dividends_std': 0.0030174171621927827,
#    'dividends_percent_std': 0.002763852855891117,
#    'price_std': 0.016276745809408782}],
#  ['000254',
#   '长城定开债A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.06120207470219194,
#    'dividends_std': 0.0030174171621927827,
#    'dividends_percent_std': 0.0027581306495961548,
#    'price_std': 0.015992754586071543}],
#  ['000277',
#   '博时双月薪定期支付债券',
#   {'dividends_count': 6,
#    'anual_dividends_percent': 0.060406085270400256,
#    'dividends_std': 0.002880131742548662,
#    'dividends_percent_std': 0.0028943888553203127,
#    'price_std': 0.006972479681643201}],
#  ['000887',
#   '上投摩根稳进回报混合',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.059928432032204784,
#    'dividends_std': 0.0019635166371436375,
#    'dividends_percent_std': 0.0019220639354236167,
#    'price_std': 0.014049121475881152}],
#  ['002550',
#   '嘉实稳荣债券',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.059177882937046664,
#    'dividends_std': 0.002740674058337501,
#    'dividends_percent_std': 0.002698415079081715,
#    'price_std': 0.011243946031784439}],
#  ['001794',
#   '兴银朝阳债券',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.058916926470284584,
#    'dividends_std': 0.0027480345935680817,
#    'dividends_percent_std': 0.0027003292412700556,
#    'price_std': 0.01294223287355919}],
#  ['000898',
#   '华富恒稳纯债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.05880756355740523,
#    'dividends_std': 0.004144214113746389,
#    'dividends_percent_std': 0.003749402075225177,
#    'price_std': 0.022252724165324332}],
#  ['000069',
#   '国投瑞银中高等级债券A',
#   {'dividends_count': 12,
#    'anual_dividends_percent': 0.05829923278645511,
#    'dividends_std': 0.0012210427672281795,
#    'dividends_percent_std': 0.001110892274610714,
#    'price_std': 0.010979015234081978}],
#  ['001802',
#   '易方达瑞财混合I',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.057823159127506955,
#    'dividends_std': 0.0032770858947672745,
#    'dividends_percent_std': 0.0027737744869117406,
#    'price_std': 0.022555763099030648}],
#  ['000138',
#   '民生加银岁岁增利债券C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.057578085573520676,
#    'dividends_std': 0.0029331010976688457,
#    'dividends_percent_std': 0.0025969871259422673,
#    'price_std': 0.01261223532130935}],
#  ['000138',
#   '民生加银岁岁增利债券C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.057578085573520676,
#    'dividends_std': 0.0029331010976688457,
#    'dividends_percent_std': 0.0025969871259422673,
#    'price_std': 0.01261223532130935}],
#  ['000138',
#   '民生加银岁岁增利债券C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.057578085573520676,
#    'dividends_std': 0.0029331010976688457,
#    'dividends_percent_std': 0.0025969871259422673,
#    'price_std': 0.01261223532130935}],
#  ['000138',
#   '民生加银岁岁增利债券C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.057578085573520676,
#    'dividends_std': 0.0029331010976688457,
#    'dividends_percent_std': 0.0025969871259422673,
#    'price_std': 0.01261223532130935}],
#  ['001803',
#   '易方达瑞财混合E',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.057577931199378346,
#    'dividends_std': 0.003251798592440434,
#    'dividends_percent_std': 0.0027825860777197326,
#    'price_std': 0.02189407158750708}],
#  ['002501',
#   '银华远景债券',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.056907435364441615,
#    'dividends_std': 0.00300187363399133,
#    'dividends_percent_std': 0.002630801716796868,
#    'price_std': 0.010548750397263816}],
#  ['002436',
#   '上投摩根红利回报混合C',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.05587809261909968,
#    'dividends_std': 0.0019107180560964468,
#    'dividends_percent_std': 0.0018674766163626715,
#    'price_std': 0.016049029130171897}],
#  ['002036',
#   '安信优势增长混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.055572779414044336,
#    'dividends_std': 0.00914277390632665,
#    'dividends_percent_std': 0.003543161489043035,
#    'price_std': 0.13131787866525585}],
#  ['001287',
#   '安信优势增长混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.055557690091059285,
#    'dividends_std': 0.009219282474580422,
#    'dividends_percent_std': 0.0035421994369617816,
#    'price_std': 0.13337128275753307}],
#  ['000070',
#   '国投瑞银中高等级债券C',
#   {'dividends_count': 12,
#    'anual_dividends_percent': 0.0547756210076224,
#    'dividends_std': 0.0011768274932084759,
#    'dividends_percent_std': 0.0010729345876335028,
#    'price_std': 0.011554911005564794}],
#  ['002073',
#   '圆信永丰兴融A',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.05432176647590134,
#    'dividends_std': 0.0017850319396039054,
#    'dividends_percent_std': 0.0017629897503849258,
#    'price_std': 0.00601480057074818}],
#  ['000047',
#   '华夏双债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.054298941798941805,
#    'dividends_std': 0.005234461211362748,
#    'dividends_percent_std': 0.003461945245610283,
#    'price_std': 0.04785841362918376}],
#  ['000047',
#   '华夏双债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.054298941798941805,
#    'dividends_std': 0.005234461211362748,
#    'dividends_percent_std': 0.003461945245610283,
#    'price_std': 0.04785841362918376}],
#  ['000047',
#   '华夏双债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.054298941798941805,
#    'dividends_std': 0.005234461211362748,
#    'dividends_percent_std': 0.003461945245610283,
#    'price_std': 0.04785841362918376}],
#  ['000047',
#   '华夏双债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.054298941798941805,
#    'dividends_std': 0.005234461211362748,
#    'dividends_percent_std': 0.003461945245610283,
#    'price_std': 0.04785841362918376}],
#  ['001756',
#   '嘉实策略优选混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.053223388305847066,
#    'dividends_std': 0.004526756955015285,
#    'dividends_percent_std': 0.0033933710307460898,
#    'price_std': 0.04065174245873453}],
#  ['001546',
#   '博时裕盈3个月定开债',
#   {'dividends_count': 10,
#    'anual_dividends_percent': 0.0529281399039763,
#    'dividends_std': 0.0011619266196226659,
#    'dividends_percent_std': 0.0011553568721225334,
#    'price_std': 0.004942710255826541}],
#  ['000246',
#   '博时月月薪定期支付债券',
#   {'dividends_count': 12,
#    'anual_dividends_percent': 0.05229506329692013,
#    'dividends_std': 0.0016842748668681499,
#    'dividends_percent_std': 0.0016618047458763342,
#    'price_std': 0.006149141572202189}],
#  ['001755',
#   '嘉实新思路混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.052057094878253565,
#    'dividends_std': 0.0039529426931119395,
#    'dividends_percent_std': 0.0033190114971552807,
#    'price_std': 0.03865678795904138}],
#  ['002438',
#   '创金合信尊盛纯债',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.05189028319636496,
#    'dividends_std': 0.0023551621680861323,
#    'dividends_percent_std': 0.002349928345615312,
#    'price_std': 0.008571481049402039}],
#  ['002056',
#   '中银新财富混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.051709027169149865,
#    'dividends_std': 0.0037616712724774914,
#    'dividends_percent_std': 0.0032968196954228676,
#    'price_std': 0.020437213609612946}],
#  ['001796',
#   '汇添富安鑫智选混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.05166931637519873,
#    'dividends_std': 0.004144214113746388,
#    'dividends_percent_std': 0.0032942878487650135,
#    'price_std': 0.10936433605537496}],
#  ['002206',
#   '博时裕康纯债债券',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.051556515761563386,
#    'dividends_std': 0.0033472498611028505,
#    'dividends_percent_std': 0.0032870960042255238,
#    'price_std': 0.016147408816748594}],
#  ['002054',
#   '中银新财富混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.05152838427947598,
#    'dividends_std': 0.0037616712724774914,
#    'dividends_percent_std': 0.0032853024213777204,
#    'price_std': 0.0208727350959892}],
#  ['000048',
#   '华夏双债债券C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.051511081262592344,
#    'dividends_std': 0.004890172654220739,
#    'dividends_percent_std': 0.0032841992305041898,
#    'price_std': 0.04648619720532371}],
#  ['000048',
#   '华夏双债债券C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.051511081262592344,
#    'dividends_std': 0.004890172654220739,
#    'dividends_percent_std': 0.0032841992305041898,
#    'price_std': 0.04648619720532371}],
#  ['000048',
#   '华夏双债债券C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.051511081262592344,
#    'dividends_std': 0.004890172654220739,
#    'dividends_percent_std': 0.0032841992305041898,
#    'price_std': 0.04648619720532371}],
#  ['000048',
#   '华夏双债债券C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.051511081262592344,
#    'dividends_std': 0.004890172654220739,
#    'dividends_percent_std': 0.0032841992305041898,
#    'price_std': 0.04648619720532371}],
#  ['000812',
#   '富国收益增强债券C',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.051510989010989015,
#    'dividends_std': 0.003381848797792222,
#    'dividends_percent_std': 0.00232269835013202,
#    'price_std': 0.040256322839148886}],
#  ['002431',
#   '中银丰利混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.05142332415059688,
#    'dividends_std': 0.0035703998518430416,
#    'dividends_percent_std': 0.0032786040880101396,
#    'price_std': 0.039801715119418074}],
#  ['002430',
#   '中银丰利混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.05137614678899082,
#    'dividends_std': 0.0035703998518430416,
#    'dividends_percent_std': 0.0032755961943514147,
#    'price_std': 0.03999437194891932}],
#  ['000221',
#   '汇添富年年利定开债A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.05076923076923077,
#    'dividends_std': 0.004207971253957873,
#    'dividends_percent_std': 0.003236900964582976,
#    'price_std': 0.029996627326730592}],
#  ['002074',
#   '圆信永丰兴融C',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.050415079546612104,
#    'dividends_std': 0.001664005094023536,
#    'dividends_percent_std': 0.0016451319006477976,
#    'price_std': 0.0055689147352615456}],
#  ['002211',
#   '嘉实新财富混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.05016722408026756,
#    'dividends_std': 0.0038254284126889738,
#    'dividends_percent_std': 0.0031985187397064996,
#    'price_std': 0.034950840468855444}],
#  ['002143',
#   '博时裕坤3个月定开债',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.0501658257144986,
#    'dividends_std': 0.004901668607748478,
#    'dividends_percent_std': 0.004603062662838284,
#    'price_std': 0.015212238385536873}],
#  ['000810',
#   '富国收益增强债券A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.0499356605465507,
#    'dividends_std': 0.003381848797792222,
#    'dividends_percent_std': 0.002251765072172579,
#    'price_std': 0.0432880309976689}],
#  ['002466',
#   '博时裕新纯债',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04905808477237048,
#    'dividends_std': 0.0031878570105741445,
#    'dividends_percent_std': 0.003127803189338839,
#    'price_std': 0.014703977821157704}],
#  ['002158',
#   '汇添富安鑫智选混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04894578313253012,
#    'dividends_std': 0.004144214113746388,
#    'dividends_percent_std': 0.003120643157941557,
#    'price_std': 0.11428144452665405}],
#  ['001932',
#   '国寿安保灵活优选混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.047929736511919695,
#    'dividends_std': 0.00365328413411797,
#    'dividends_percent_std': 0.003055862931089895,
#    'price_std': 0.024821160156276743}],
#  ['000556',
#   '国投瑞银新机遇灵活配置混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.047861906630051,
#    'dividends_std': 0.00777837110580091,
#    'dividends_percent_std': 0.0030515382918010663,
#    'price_std': 0.048261620431393426}],
#  ['001299',
#   '兴业添利债券',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.04773805566075546,
#    'dividends_std': 0.0015314337931245556,
#    'dividends_percent_std': 0.001522672868394195,
#    'price_std': 0.005982589678278321}],
#  ['001711',
#   '安信新趋势混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04766444232602479,
#    'dividends_std': 0.0031878570105741445,
#    'dividends_percent_std': 0.0030389485324825026,
#    'price_std': 0.015642473603136538}],
#  ['001710',
#   '安信新趋势混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04757373929590866,
#    'dividends_std': 0.0031878570105741445,
#    'dividends_percent_std': 0.003033165566673783,
#    'price_std': 0.01595969308649901}],
#  ['001104',
#   '华安新丝路主题股票A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.047455415397999134,
#    'dividends_std': 0.006955903997072782,
#    'dividends_percent_std': 0.0030256215733243967,
#    'price_std': 0.23575676493279785}],
#  ['001578',
#   '博时裕瑞纯债债券',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04741379310344828,
#    'dividends_std': 0.0035066427116315596,
#    'dividends_percent_std': 0.0030229678548547925,
#    'price_std': 0.019136487665798462}],
#  ['002447',
#   '博时裕安纯债定开债发起式',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04719188767550701,
#    'dividends_std': 0.006354253246310832,
#    'dividends_percent_std': 0.006195644740942701,
#    'price_std': 0.014143115832587452}],
#  ['000016',
#   '华夏纯债债券C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.047119518486672396,
#    'dividends_std': 0.003493891283589263,
#    'dividends_percent_std': 0.0030042057468523337,
#    'price_std': 0.017604938536992843}],
#  ['000015',
#   '华夏纯债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04707357859531773,
#    'dividends_std': 0.003589526993906486,
#    'dividends_percent_std': 0.0030012767507579313,
#    'price_std': 0.01786578030171798}],
#  ['001720',
#   '工银新增利混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.047008547008547015,
#    'dividends_std': 0.0035066427116315605,
#    'dividends_percent_std': 0.0029971305227620166,
#    'price_std': 0.02121091009846894}],
#  ['002520',
#   '招商招瑞纯债发起式C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04687499999999999,
#    'dividends_std': 0.003251614150785628,
#    'dividends_percent_std': 0.00298861594741326,
#    'price_std': 0.015547117191875966}],
#  ['002356',
#   '博时安泰18个月定开债A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.046772684752104776,
#    'dividends_std': 0.0060627152273402705,
#    'dividends_percent_std': 0.005671389361403434,
#    'price_std': 0.01897373640591538}],
#  ['001194',
#   '景顺长城稳健回报混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04669540229885058,
#    'dividends_std': 0.0041442141137463875,
#    'dividends_percent_std': 0.002977165311599416,
#    'price_std': 0.03130109211108997}],
#  ['000557',
#   '国投瑞银新机遇灵活配置混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04642712959224869,
#    'dividends_std': 0.00733207112432053,
#    'dividends_percent_std': 0.002960061011029686,
#    'price_std': 0.046175671657932855}],
#  ['002341',
#   '招商招瑞纯债发起式A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04640582347588717,
#    'dividends_std': 0.003251614150785628,
#    'dividends_percent_std': 0.0029587025939814614,
#    'price_std': 0.015646218870106532}],
#  ['001407',
#   '景顺长城稳健回报混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.046255506607929514,
#    'dividends_std': 0.004016699833323424,
#    'dividends_percent_std': 0.0029491188203549347,
#    'price_std': 0.030809619489069053}],
#  ['002103',
#   '招商康泰灵活配置混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04612365063788028,
#    'dividends_std': 0.002996585589939696,
#    'dividends_percent_std': 0.0029407120607847855,
#    'price_std': 0.04350838453904989}],
#  ['000355',
#   '南方丰元信用增强债券A',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.04605411911184036,
#    'dividends_std': 0.002132577246968024,
#    'dividends_percent_std': 0.0016902977827924592,
#    'price_std': 0.011196296942419122}],
#  ['000222',
#   '汇添富年年利定开债C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04574132492113565,
#    'dividends_std': 0.003697914132266009,
#    'dividends_percent_std': 0.0029163360664558415,
#    'price_std': 0.027851981580625705}],
#  ['002507',
#   '兴业定开债C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04570383912248629,
#    'dividends_std': 0.006454045004969415,
#    'dividends_percent_std': 0.005899492691928166,
#    'price_std': 0.0156235151549574}],
#  ['002486',
#   '上银慧添利债券',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.0448746052023868,
#    'dividends_std': 0.0015296987750395015,
#    'dividends_percent_std': 0.00152532876042745,
#    'price_std': 0.004529803200423722}],
#  ['000546',
#   '兴业定开债A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04476275738585497,
#    'dividends_std': 0.006454045004969415,
#    'dividends_percent_std': 0.0057780170142967,
#    'price_std': 0.01517520013786839}],
#  ['002058',
#   '中银新机遇混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04476190476190476,
#    'dividends_std': 0.0029965855899396964,
#    'dividends_percent_std': 0.0028538910380378063,
#    'price_std': 0.022831117107393394}],
#  ['002057',
#   '中银新机遇混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04471931493815414,
#    'dividends_std': 0.0029965855899396964,
#    'dividends_percent_std': 0.0028511756326733547,
#    'price_std': 0.023321007434394886}],
#  ['000297',
#   '鹏华可转债债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.044427123928293066,
#    'dividends_std': 0.0036341569920545244,
#    'dividends_percent_std': 0.002832546369489107,
#    'price_std': 0.11200396063086898}],
#  ['000053',
#   '鹏华永诚一年定开债券',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.043779659930831626,
#    'dividends_std': 0.0018855842344057624,
#    'dividends_percent_std': 0.0018664136050827794,
#    'price_std': 0.007991423078244173}],
#  ['000188',
#   '华泰柏瑞丰盛纯债债券C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04369898467051563,
#    'dividends_std': 0.0027989384552840994,
#    'dividends_percent_std': 0.0027861222927375064,
#    'price_std': 0.017499279052204934}],
#  ['000188',
#   '华泰柏瑞丰盛纯债债券C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04369898467051563,
#    'dividends_std': 0.0027989384552840994,
#    'dividends_percent_std': 0.0027861222927375064,
#    'price_std': 0.017499279052204934}],
#  ['001179',
#   '德邦大健康灵活配置混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04320876211109105,
#    'dividends_std': 0.0045777626671844734,
#    'dividends_percent_std': 0.002754867104281441,
#    'price_std': 0.059521493736098614}],
#  ['001619',
#   '兴银汇福定开债',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.04319183379468594,
#    'dividends_std': 0.001688010493225526,
#    'dividends_percent_std': 0.001659112520495964,
#    'price_std': 0.0070626453684272325}],
#  ['000356',
#   '南方丰元信用增强债券C',
#   {'dividends_count': 3,
#    'anual_dividends_percent': 0.04312377617778061,
#    'dividends_std': 0.001962603987222644,
#    'dividends_percent_std': 0.001588121775680976,
#    'price_std': 0.010489866830539317}],
#  ['000754',
#   '华宝量化对冲混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04311459860308701,
#    'dividends_std': 0.0031878570105741445,
#    'dividends_percent_std': 0.002748863508298822,
#    'price_std': 0.015283569855846045}],
#  ['001783',
#   '兴银合盈债券A',
#   {'dividends_count': 6,
#    'anual_dividends_percent': 0.04296884391642075,
#    'dividends_std': 0.0011637517064015143,
#    'dividends_percent_std': 0.001160610666982275,
#    'price_std': 0.0038779023686147888}],
#  ['001784',
#   '兴银合盈债券C',
#   {'dividends_count': 6,
#    'anual_dividends_percent': 0.04286818889305359,
#    'dividends_std': 0.0011637517064015143,
#    'dividends_percent_std': 0.0011579684482283495,
#    'price_std': 0.0035144140392319163}],
#  ['000753',
#   '华宝量化对冲混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04250255015300919,
#    'dividends_std': 0.0031878570105741445,
#    'dividends_percent_std': 0.00270984104945099,
#    'price_std': 0.014871903488438516}],
#  ['000189',
#   '易方达丰华债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04187542062364466,
#    'dividends_std': 0.003570399851843041,
#    'dividends_percent_std': 0.0026698570641165357,
#    'price_std': 0.04811418904722185}],
#  ['000189',
#   '易方达丰华债券A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04187542062364466,
#    'dividends_std': 0.003570399851843041,
#    'dividends_percent_std': 0.0026698570641165357,
#    'price_std': 0.04811418904722185}],
#  ['001217',
#   '易方达新收益混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.041784885220531344,
#    'dividends_std': 0.010328656714260228,
#    'dividends_percent_std': 0.0026640847857261362,
#    'price_std': 0.43504627624422804}],
#  ['002600',
#   '易方达裕景添利6个月定开债',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04173622704507513,
#    'dividends_std': 0.0031878570105741445,
#    'dividends_percent_std': 0.00266098247961114,
#    'price_std': 0.028258512703105698}],
#  ['001115',
#   '广发聚安混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.041666666666666664,
#    'dividends_std': 0.003442885571420076,
#    'dividends_percent_std': 0.0026565475088117874,
#    'price_std': 0.023767135601369338}],
#  ['001116',
#   '广发聚安混合C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.041633935585231735,
#    'dividends_std': 0.003379128431208593,
#    'dividends_percent_std': 0.002654460668663466,
#    'price_std': 0.02206085861238261}],
#  ['001216',
#   '易方达新收益混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.0414989939637827,
#    'dividends_std': 0.01051992813489468,
#    'dividends_percent_std': 0.002645857176784375,
#    'price_std': 0.4474057392087015}],
#  ['002411',
#   '华夏新机遇混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04148580968280468,
#    'dividends_std': 0.0031687298685106995,
#    'dividends_percent_std': 0.0026450165847334726,
#    'price_std': 0.01963533266960941}],
#  ['000436',
#   '易方达裕惠定开混合发起式',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04140914709517923,
#    'dividends_std': 0.0042717283941693515,
#    'dividends_percent_std': 0.0026401287973852627,
#    'price_std': 0.031821925912223104}],
#  ['000899',
#   '华富恒稳纯债债券C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04124656278643447,
#    'dividends_std': 0.00286907130951673,
#    'dividends_percent_std': 0.002629762886816435,
#    'price_std': 0.014265807004140482}],
#  ['001442',
#   '易方达瑞信混合E',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.041018387553041026,
#    'dividends_std': 0.003697914132266009,
#    'dividends_percent_std': 0.002615215086468182,
#    'price_std': 0.03188837674496103}],
#  ['001352',
#   '民生加银新战略混合A',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.040957781978575934,
#    'dividends_std': 0.004144214113746389,
#    'dividends_percent_std': 0.002611351048359413,
#    'price_std': 0.031053177106588635}],
#  ['001807',
#   '易方达瑞智灵活配置混合E',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04084967320261438,
#    'dividends_std': 0.003187857010574145,
#    'dividends_percent_std': 0.00260445834197234,
#    'price_std': 0.023920855898959294}],
#  ['001246',
#   '兴银长乐定开债',
#   {'dividends_count': 4,
#    'anual_dividends_percent': 0.04074980906247262,
#    'dividends_std': 0.0013188411355648472,
#    'dividends_percent_std': 0.0013106074122412694,
#    'price_std': 0.007140797370652185}],
#  ['001136',
#   '易方达裕如混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.040731504571903575,
#    'dividends_std': 0.003124099870362662,
#    'dividends_percent_std': 0.0025969242480155122,
#    'price_std': 0.020850602433125046}],
#  ['001441',
#   '易方达瑞信混合I',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04070175438596491,
#    'dividends_std': 0.003697914132266009,
#    'dividends_percent_std': 0.002595027461239303,
#    'price_std': 0.0328426851193316}],
#  ['002357',
#   '博时安泰18个月定开债C',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.040566037735849055,
#    'dividends_std': 0.005213935095512631,
#    'dividends_percent_std': 0.00491880669387984,
#    'price_std': 0.016865222553788535}],
#  ['001433',
#   '易方达瑞景混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.040549378678875085,
#    'dividends_std': 0.003952942693111939,
#    'dividends_percent_std': 0.0025853124219175536,
#    'price_std': 0.03152828972358993}],
#  ['000419',
#   '大摩优质信价纯债A',
#   {'dividends_count': 2,
#    'anual_dividends_percent': 0.040464906616634794,
#    'dividends_std': 0.0018806299510832234,
#    'dividends_percent_std': 0.001820542519471042,
#    'price_std': 0.008053028165886822}],
#  ['000306',
#   '天弘弘利债券',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04033233846898443,
#    'dividends_std': 0.0031878570105741445,
#    'dividends_percent_std': 0.0025714745588240255,
#    'price_std': 0.013829701565751555}],
#  ['001603',
#   '易方达安盈回报混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04025256511444357,
#    'dividends_std': 0.006503228301571257,
#    'dividends_percent_std': 0.0025663884378734226,
#    'price_std': 0.19193369351733253}],
#  ['001249',
#   '易方达新利灵活配置混合',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.04015544041450777,
#    'dividends_std': 0.003952942693111939,
#    'dividends_percent_std': 0.0025601960447616183,
#    'price_std': 0.0327591185788396}],
#  ['001806',
#   '易方达瑞智灵活配置混合I',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.040096230954290296,
#    'dividends_std': 0.003187857010574145,
#    'dividends_percent_std': 0.002556421018904686,
#    'price_std': 0.0249895951692339}],
#  ['001818',
#   '易方达瑞兴灵活配置混合E',
#   {'dividends_count': 1,
#    'anual_dividends_percent': 0.040061633281972264,
#    'dividends_std': 0.0033153712909971106,
#    'dividends_percent_std': 0.0025542151702597155,
#    'price_std': 0.026942538389019985}]]

# %% [markdown]
# # interested
# 宝盈核心优势混合C
# https://fund.eastmoney.com/000241.html
# 'dividends_count': 12,
# 'anual_dividends_percent': 0.1569051502505668,
# 'dividends_std': 0.0037453288969647234,
# 'dividends_percent_std': 0.0029154833879929684,
# 'price_std': 0.11489876989310534
#
# 国联安鑫安灵活配置混合
# https://fund.eastmoney.com/001007.html
# 'dividends_count': 4,
# 'anual_dividends_percent': 0.44077288285481997,
# 'dividends_std': 0.017295682257132607,
# 'dividends_percent_std': 0.014184793634911392,
# 'price_std': 0.15585291349398883
#
# 圆信永丰双利A
# https://fund.eastmoney.com/000824.html
# 'dividends_count': 4,
# 'anual_dividends_percent': 0.4044969605364803,
# 'dividends_std': 0.01733474656291999,
# 'dividends_percent_std': 0.013409297966068084,
# 'price_std': 0.07567492502397623
#
# 华夏回报混合A
# https://fund.eastmoney.com/002001.html
# 'dividends_count': 14,
# 'anual_dividends_percent': 0.17762188421776784,
# 'dividends_std': 0.005685642497752113,
# 'dividends_percent_std': 0.0032725857559546294,
# 'price_std': 0.1412083561623124
